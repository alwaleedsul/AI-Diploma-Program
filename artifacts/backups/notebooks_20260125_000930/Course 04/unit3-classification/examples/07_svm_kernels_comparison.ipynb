# %% [markdown]
# # Using SVM with Different Kernels (Linear, Polynomial, RBF)
#
# ## 📚 Learning Objectives
#
# By completing this notebook, you will:
# - Implement SVM with linear kernel
# - Implement SVM with polynomial kernel
# - Implement SVM with RBF kernel
# - Compare kernel performance
# - Select appropriate kernel
#
# ## 🔗 Prerequisites
#
# - ✅ Understanding of SVM
# - ✅ Understanding of kernels
# - ✅ Scikit-learn knowledge
#
# ---
#
# ## Official Structure Reference
#
# This notebook covers practical activities from **Course 04, Unit 3**:
# - Using SVM with different kernels (linear, polynomial, RBF) to handle complex classification tasks
# - **Source:** `DETAILED_UNIT_DESCRIPTIONS.md` - Unit 3 Practical Content
#
# ---
#
# ## Introduction
#
# **SVM kernels** transform data into higher-dimensional spaces, enabling SVMs to handle non-linear classification problems effectively.

# %%
import numpy as np
from sklearn.svm import SVC
from sklearn.model_selection import cross_val_score
import matplotlib.pyplot as plt_
print("✅ Libraries imported!")
print("\nSVM with Different Kernels")
print("=" * 60)

print("\nLinear Kernel:")
print("  - For linearly separable data")
print("  - Fast, simple")
print("  - No parameters")

print("\nPolynomial Kernel:")
print("  - For polynomial boundaries")
print("  - Degree parameter")
print("  - More flexible")

print("\nRBF (Radial Basis Function) Kernel:")
print("  - For complex boundaries")
print("  - Gamma parameter")
print("  - Most flexible")

print("\n✅ SVM kernels concepts understood!")
