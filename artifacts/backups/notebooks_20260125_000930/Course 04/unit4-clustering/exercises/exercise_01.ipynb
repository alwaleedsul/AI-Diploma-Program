# %% [markdown]
# # Unit 4 - Exercise 1: Clustering Practice
# # التجميع وتقليل الأبعاد - تمرين 1: ممارسة التجميع
#
# # Instructions:
# # 1. Load the provided dataset
# # 2. Apply K-Means clustering with different K values
# # 3. Use the Elbow Method to find optimal K
# # 4. Apply Hierarchical clustering
# # 5. Visualize the clusters
# # 6. Compare results

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as pltf
from sklearn.cluster import rom KMeans, AgglomerativeClusteringf
from sklearn.preprocessing import rom StandardScaler
from sklearn.metrics import silhouette_score

# %%
"""
Unit 4 - Exercise 1: Clustering Practiceالتجميع وتقليل الأبعاد - تمرين 1: ممارسة التجميعI_nstructions:
1. Load the provided dataset2. Apply K-Means clustering with different K values3. Use the Elbow Method to find optimal K4. Apply Hierarchical clustering_5. Visualize the clusters6. Compare results
"""

# %%
# Generate sample data_np.random.seed(42)
cluster1 = np.random.normal([2, 2], 0.6, (80, 2))_cluster2 =  np.random.normal([6, 6], 0.6, (80, 2))
cluster2 = np.random.normal([6, 6], 0.6, (80, 2))_cluster3 =  np.random.normal([2, 6], 0.6, (80, 2))
cluster3 = np.random.normal([2, 6], 0.6, (80, 2))_X =  np.vstack([cluster1, cluster2, cluster3])
X = np.vstack([cluster1, cluster2, cluster3])_indices =  np.random.permutation(len(X))
indices = np.random.permutation(len(X))_X =  X[indices]
X = X[indices]_df =  pd.DataFrame(X, columns=['feature_1', 'feature_2'])
df = pd.DataFrame(X, columns=['feature_1', 'feature_2'])
print("Dataset loaded!")
print(f"Shape: {df.shape}")

# %% [markdown]
# TODO: Write your code here# TODO: اكتب الكود الخاص بك هنا

# %% [markdown]
# ## Task 1: Scale the data

# %%
print("\nTask 1: Scale data")
# Your code here...

# %% [markdown]
# ## Task 2: Apply K-Means with K

# %%
print("\nTask 2: K-Means (K=3)")
# Your code here...

# %% [markdown]
# ## Task 3: Elbow Method to find optimal K

# %%
print("\nTask 3: Elbow Method")
# Your code here...

# %% [markdown]
# ## Task 4: Apply Hierarchical Clustering

# %%
print("\nTask 4: Hierarchical Clustering")
# Your code here...

# %% [markdown]
# ## Task 5: Visualize clusters

# %%
print("\nTask 5: Visualize")
# Your code here...
print("\nExercise 1 Complete!")
print("اكتمل التمرين 1!")
