# %% [markdown]
# # Using Elbow Method and Silhouette Score to Determine Optimal Number of Clusters
#
# ## 📚 Learning Objectives
#
# By completing this notebook, you will:
# - Implement the Elbow method
# - Compute Silhouette scores
# - Determine optimal number of clusters
# - Visualize cluster quality metrics
# - Apply to clustering problems
#
# ## 🔗 Prerequisites
#
# - ✅ Understanding of clustering
# - ✅ Understanding of K-Means
# - ✅ Scikit-learn knowledge
#
# ---
#
# ## Official Structure Reference
#
# This notebook covers practical activities from **Course 04, Unit 4**:
# - Using Elbow method and Silhouette score to determine optimal number of clusters
# - **Source:** `DETAILED_UNIT_DESCRIPTIONS.md` - Unit 4 Practical Content
#
# ---
#
# ## Introduction
#
# **Elbow method** and **Silhouette score** are techniques to determine the optimal number of clusters in K-Means clustering, helping balance between too few and too many clusters.

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.cluster 
import KMeans
from sklearn.metrics 
import silhouette_score
from sklearn.datasets 
import make_blobs_
print("✅ Libraries imported!")
print("\nElbow Method and Silhouette Score")
print("=" * 60)

print("\nElbow Method:")
print("  - Plot within-cluster sum of squares (WCSS)")
print("  - Look for 'elbow' in the curve")
print("  - Indicates optimal k")

print("\nSilhouette Score:")
print("  - Measures cluster quality")
print("  - Range: -1 to 1")
print("  - Higher is better")
print("  - Compare across different k values")

print("\n✅ Cluster optimization concepts understood!")
