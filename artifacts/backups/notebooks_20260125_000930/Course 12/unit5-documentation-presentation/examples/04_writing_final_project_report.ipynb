# %% [markdown]
# # Writing Final Project Report (Summary, Methodology, Results, Discussion)
#
# ## 📚 Learning Objectives
#
# By completing this notebook, you will:
# - Write comprehensive project report
# - Structure report sections
# - Document methodology
# - Present results effectively
# - Discuss findings
#
# ## 🔗 Prerequisites
#
# - ✅ Understanding of technical writing
# - ✅ Understanding of project documentation
# - ✅ Report writing skills
#
# ---
#
# ## Official Structure Reference
#
# This notebook covers practical activities from **Course 12, Unit 5**:
# - Writing final project report (including summary, methodology, results, discussion)
# - **Source:** `DETAILED_UNIT_DESCRIPTIONS.md` - Unit 5 Practical Content
#
# ---
#
# ## Introduction
#
# **Project reports** document the complete AI project lifecycle, including problem definition, methodology, results, and discussion of findings and implications.

# %%
print("✅ Libraries imported!")
print("\nWriting Final Project Report")
print("=" * 60)

print("\nReport Structure:")
print("  1. Abstract/Summary")
print("  2. Introduction")
print("  3. Literature Review")
print("  4. Methodology")
print("  5. Results")
print("  6. Discussion")
print("  7. Conclusion")

print("\nKey Sections:")
print("  - Problem statement")
print("  - Technical approach")
print("  - Implementation details")
print("  - Experimental results")
print("  - Analysis and discussion")

print("\nBest Practices:")
print("  - Clear structure")
print("  - Visualizations")
print("  - Code snippets")
print("  - Reproducibility")
print("  - References")

print("\n✅ Project report writing concepts understood!")
