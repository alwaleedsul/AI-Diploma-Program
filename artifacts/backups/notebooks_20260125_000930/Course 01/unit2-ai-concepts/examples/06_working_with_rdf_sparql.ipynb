# %% [markdown]
# # Working with RDF and SPARQL for Knowledge Graph Queries
#
# ## 📚 Learning Objectives
#
# By completing this notebook, you will:
# - Work with RDF (Resource Description Framework)
# - Write SPARQL queries
# - Query knowledge graphs
# - Extract information from RDF data
# - Apply to knowledge representation
#
# ## 🔗 Prerequisites
#
# - ✅ Understanding of RDF
# - ✅ Understanding of SPARQL
# - ✅ Knowledge graphs basics
#
# ---
#
# ## Official Structure Reference
#
# This notebook covers practical activities from **Course 01, Unit 2**:
# - Working with RDF and SPARQL for knowledge graph queries
# - **Source:** `DETAILED_UNIT_DESCRIPTIONS.md` - Unit 2 Practical Content
#
# ---
#
# ## Introduction
#
# **RDF and SPARQL** enable structured knowledge representation and querying, forming the foundation of semantic web technologies.

# %%
from rdflib import Graph, Namespace
from SPARQLWrapper import SPARQLWrapper, JSON

print("✅ Libraries imported!")
print("\nWorking with RDF and SPARQL")
print("=" * 60)

print("\nRDF (Resource Description Framework):")
print(" - Triples: Subject-Predicate-Object")
print(" - Graph-based representation")
print(" - Semantic web standard")
print(" - Knowledge graphs")

print("\nSPARQL:")
print(" - Query language for RDF")
print(" - SELECT queries")
print(" - CONSTRUCT queries")
print(" - ASK queries")

print("\nApplications:")
print(" - Knowledge graphs")
print(" - Semantic search")
print(" - Data integration")
print(" - Linked data")

print("\n✅ RDF/SPARQL concepts understood!")
