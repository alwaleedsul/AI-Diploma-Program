# %% [markdown]
# # Working with RDF and SPARQL for Knowledge Graph Queries
#
# ## 📚 Learning Objectives
#
# By completing this notebook, you will:
# - Work with RDF (Resource Description Framework)
# - Write SPARQL queries
# - Query knowledge graphs
# - Extract structured information
# - Apply to knowledge representation
#
# ## 🔗 Prerequisites
#
# - ✅ Understanding of knowledge graphs
# - ✅ Understanding of RDF
# - ✅ SPARQL basics
#
# ---
#
# ## Official Structure Reference
#
# This notebook covers practical activities from **Course 01, Unit 2**:
# - Working with RDF and SPARQL for knowledge graph queries
# - **Source:** `DETAILED_UNIT_DESCRIPTIONS.md` - Unit 2 Practical Content
#
# ---
#
# ## Introduction
#
# **RDF and SPARQL** enable structured knowledge representation and querying, forming the foundation of semantic web technologies and knowledge graphs.

# %%
from rdflib import Graph, Namespace, Literal
from rdflib.namespace import RDF, RDFS

print("✅ Libraries imported!")
print("\nWorking with RDF and SPARQL")
print("=" * 60)

print("\nRDF (Resource Description Framework):")
print("  - Triple structure: Subject-Predicate-Object")
print("  - Graph-based representation")
print("  - Standard format for knowledge graphs")

print("\nSPARQL:")
print("  - Query language for RDF")
print("  - Similar to SQL for databases")
print("  - Pattern matching queries")

print("\nApplications:")
print("  - Knowledge graphs")
print("  - Semantic web")
print("  - Linked data")
print("  - Ontology queries")

print("\n✅ RDF/SPARQL concepts understood!")
