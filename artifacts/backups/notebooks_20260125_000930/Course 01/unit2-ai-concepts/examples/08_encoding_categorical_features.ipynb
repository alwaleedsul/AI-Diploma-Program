# %% [markdown]
# # Encoding Categorical Features for ML Models
#
# ## 📚 Learning Objectives
#
# By completing this notebook, you will:
# - Encode categorical features
# - Use label encoding
# - Use one-hot encoding
# - Use ordinal encoding
# - Apply to ML models
#
# ## 🔗 Prerequisites
#
# - ✅ Understanding of ML preprocessing
# - ✅ Understanding of categorical data
# - ✅ Scikit-learn knowledge
#
# ---
#
# ## Official Structure Reference
#
# This notebook covers practical activities from **Course 01, Unit 2**:
# - Encoding categorical features for ML models
# - **Source:** `DETAILED_UNIT_DESCRIPTIONS.md` - Unit 2 Practical Content
#
# ---
#
# ## Introduction
#
# **Categorical encoding** converts categorical data into numerical format that machine learning models can process, using techniques like label encoding, one-hot encoding, and ordinal encoding.

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import LabelEncoder, OneHotEncoder, OrdinalEncoder

print("✅ Libraries imported!")
print("\nEncoding Categorical Features")
print("=" * 60)

print("\nEncoding Methods:")
print("  - Label Encoding: Assigns integer labels")
print("  - One-Hot Encoding: Creates binary columns")
print("  - Ordinal Encoding: Preserves order")
print("  - Target Encoding: Uses target statistics")

print("\nWhen to Use:")
print("  - Label: Ordinal categories")
print("  - One-Hot: Nominal categories")
print("  - Ordinal: Ordered categories")

print("\n✅ Categorical encoding concepts understood!")
