# %% [markdown]
# # Implementing Regression and Classification Models Using Python
#
# ## 📚 Learning Objectives
#
# By completing this notebook, you will:
# - Implement regression models
# - Implement classification models
# - Use scikit-learn
# - Train and evaluate models
# - Apply to real datasets
#
# ## 🔗 Prerequisites
#
# - ✅ Understanding of ML concepts
# - ✅ Understanding of regression
# - ✅ Understanding of classification
# - ✅ Scikit-learn knowledge
#
# ---
#
# ## Official Structure Reference
#
# This notebook covers practical activities from **Course 01, Unit 3**:
# - Implementing regression and classification models using Python
# - **Source:** `DETAILED_UNIT_DESCRIPTIONS.md` - Unit 3 Practical Content
#
# ---
#
# ## Introduction
#
# **Regression and classification** are fundamental supervised learning tasks, with regression predicting continuous values and classification predicting discrete categories.

# %%
import pandas as pd
import numpy as np
from sklearn.linear_model import LinearRegression, LogisticRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, accuracy_score

print("✅ Libraries imported!")
print("\nImplementing Regression and Classification")
print("=" * 60)

print("\nRegression:")
print("  - Predict continuous values")
print("  - Linear Regression")
print("  - Evaluation: MSE, RMSE, R²")

print("\nClassification:")
print("  - Predict discrete categories")
print("  - Logistic Regression")
print("  - Evaluation: Accuracy, Precision, Recall")

print("\nWorkflow:")
print("  1. Load and prepare data")
print("  2. Split train/test")
print("  3. Train model")
print("  4. Evaluate performance")

print("\n✅ Regression/classification concepts understood!")
