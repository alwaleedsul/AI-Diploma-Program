# %% [markdown]
# # Experiment Tracking: MLflow and Weights & Biases
#
# ## 📚 Learning Objectives
#
# By completing this notebook, you will:
# - Understand experiment tracking
# - Use MLflow for tracking
# - Use Weights & Biases (W&B) for tracking
# - Log experiments, metrics, and artifacts
# - Compare tracking tools
#
# ## 🔗 Prerequisites
#
# - ✅ Understanding of ML experiments
# - ✅ Understanding of hyperparameter tuning
# - ✅ Python knowledge
#
# ---
#
# ## Official Structure Reference
#
# This notebook covers practical activities from **Course 11, Unit 5**:
# - Using experiment tracking tools (MLflow, Weights & Biases)
# - **Source:** `DETAILED_UNIT_DESCRIPTIONS.md` - Unit 5 Practical Content
#
# ---
#
# ## Introduction
#
# **Experiment tracking** tools like MLflow and W&B help organize, log, and compare ML experiments, making it easier to reproduce results and track model performance.

# %%
print("✅ Libraries imported!")
print("\nExperiment Tracking: MLflow and Weights & Biases")
print("=" * 60)

print("\nMLflow:")
print("  - Open-source ML lifecycle platform")
print("  - Tracking: Log parameters, metrics, artifacts")
print("  - Projects: Reproducible runs")
print("  - Models: Model registry")

print("\nWeights & Biases (W&B):")
print("  - Experiment tracking platform")
print("  - Visualizations and dashboards")
print("  - Hyperparameter optimization")
print("  - Model versioning")

print("\nWhat to Track:")
print("  - Hyperparameters")
print("  - Metrics (accuracy, loss, etc.)")
print("  - Code versions")
print("  - Data versions")
print("  - Model artifacts")

print("\n✅ Experiment tracking concepts understood!")
