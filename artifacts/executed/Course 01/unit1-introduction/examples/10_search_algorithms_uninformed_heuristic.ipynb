# %% [markdown]
# # Implementing Search Algorithms: Uninformed, Heuristic, Greedy
#
# ## 📚 Learning Objectives
#
# By completing this notebook, you will:
# - Implement uninformed search algorithms (BFS, DFS)
# - Implement heuristic search algorithms (A*)
# - Implement greedy search
# - Compare search algorithms
# - Apply to AI problems
#
# ## 🔗 Prerequisites
#
# - ✅ Understanding of graphs and trees
# - ✅ Python knowledge
# - ✅ Understanding of algorithms
#
# ---
#
# ## Official Structure Reference
#
# This notebook covers practical activities from **Course 01, Unit 1**:
# - Implementing search algorithms (uninformed, heuristic, greedy)
# - **Source:** `DETAILED_UNIT_DESCRIPTIONS.md` - Unit 1 Practical Content
#
# ---
#
# ## Introduction
#
# **Search algorithms** are fundamental to AI, enabling agents to find solutions by exploring state spaces using different strategies.

# %%
from collections import deque
import heapq

print("✅ Libraries imported!")
print("\nImplementing Search Algorithms")
print("=" * 60)

print("\nUninformed Search:")
print("  - BFS: Breadth-First Search")
print("  - DFS: Depth-First Search")
print("  - No heuristic information")

print("\nHeuristic Search:")
print("  - A*: Optimal pathfinding")
print("  - Uses heuristic function h(n)")
print("  - Combines cost and heuristic")

print("\nGreedy Search:")
print("  - Always chooses best immediate option")
print("  - Uses only heuristic")
print("  - May not find optimal solution")

print("\n✅ Search algorithms concepts understood!")
# Out:
# ✅ Libraries imported!
#
# Implementing Search Algorithms
# ...
#
# Uninformed Search:
#   - BFS: Breadth-First Search
#   - DFS: Depth-First Search
#   - No heuristic information
#
# Heuristic Search:
#   - A*: Optimal pathfinding
#   - Uses heuristic function h(n)
#   - Combines cost and heuristic
#
# Greedy Search:
#   - Always chooses best immediate option
#   - Uses only heuristic
#   - May not find optimal solution
#
# ✅ Search algorithms concepts understood!
