# %% [markdown]
# # Developing Simple Supervised and Unsupervised Learning Models
#
# ## 📚 Learning Objectives
#
# By completing this notebook, you will:
# - Build supervised learning models
# - Build unsupervised learning models
# - Compare model types
# - Apply to real datasets
# - Evaluate model performance
#
# ## 🔗 Prerequisites
#
# - ✅ Understanding of ML concepts
# - ✅ Understanding of supervised learning
# - ✅ Understanding of unsupervised learning
# - ✅ Scikit-learn knowledge
#
# ---
#
# ## Official Structure Reference
#
# This notebook covers practical activities from **Course 01, Unit 2**:
# - Developing simple supervised and unsupervised learning models
# - **Source:** `DETAILED_UNIT_DESCRIPTIONS.md` - Unit 2 Practical Content
#
# ---
#
# ## Introduction
#
# **Supervised learning** uses labeled data to make predictions, while **unsupervised learning** finds patterns in unlabeled data.

# %%
import pandas as pd
import numpy as np
from sklearn.linear_model import LinearRegression, LogisticRegression
from sklearn.cluster import KMeans
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, mean_squared_error

print("✅ Libraries imported!")
print("\nSupervised and Unsupervised Learning Models")
print("=" * 60)

print("\nSupervised Learning:")
print("  - Regression: Predict continuous values")
print("  - Classification: Predict discrete categories")
print("  - Examples: Linear Regression, Logistic Regression")

print("\nUnsupervised Learning:")
print("  - Clustering: Group similar data")
print("  - Dimensionality Reduction: Reduce features")
print("  - Examples: K-Means, PCA")

print("\nWorkflow:")
print("  1. Load and prepare data")
print("  2. Split data (supervised)")
print("  3. Train model")
print("  4. Evaluate performance")

print("\n✅ Supervised/unsupervised concepts understood!")
# Out:
# ✅ Libraries imported!
#
# Supervised and Unsupervised Learning Models
# ...
#
# Supervised Learning:
#   - Regression: Predict continuous values
#   - Classification: Predict discrete categories
#   - Examples: Linear Regression, Logistic Regression
#
# Unsupervised Learning:
#   - Clustering: Group similar data
#   - Dimensionality Reduction: Reduce features
#   - Examples: K-Means, PCA
#
# Workflow:
#   1. Load and prepare data
#   2. Split data (supervised)
#   3. Train model
#   4. Evaluate performance
#
# ✅ Supervised/unsupervised concepts understood!
