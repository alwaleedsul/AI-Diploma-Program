# %% [markdown]
# # Exercise: Package Model for Distribution
# ## AIAT 125 - Model Deployment
#
# ## Learning Objectives
#
# - Package models in different formats
# - Create model artifacts
# - Prepare for distribution
# - Apply to production deployment
#
# ## Real-World Context
#
# Package trained model for sharing and deployment.
#
# **Task**: Package model in multiple formats.
#
# ---
#
# ## Task 1: Model Packaging (40 points)
#
# Package model:
# 1. Save as Pickle
# 2. Save as ONNX
# 3. Save as SavedModel

# %%
# %pip install pickle5 onnx scikit-learn -q
import pickle
import joblib

# TODO: Load trained model
# YOUR CODE HERE

# TODO: Package in different formats
# YOUR CODE HERE
# Out:
# WARNING: Retrying (Retry(total=4, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<pip._vendor.urllib3.connection.HTTPSConnection object at 0x104ae30e0>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known')': /simple/pickle5/
# WARNING: Retrying (Retry(total=3, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<pip._vendor.urllib3.connection.HTTPSConnection object at 0x104bf0b90>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known')': /simple/pickle5/
# WARNING: Retrying (Retry(total=2, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<pip._vendor.urllib3.connection.HTTPSConnection object at 0x104bf0e10>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known')': /simple/pickle5/
# WARNING: Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<pip._vendor.urllib3.connection.HTTPSConnection object at 0x104bf1090>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known')': /simple/pickle5/
# WARNING: Retrying (Retry(total=0, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<pip._vendor.urllib3.connection.HTTPSConnection object at 0x104bf1310>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known')': /simple/pickle5/
# ERROR: Could not find a version that satisfies the requirement pickle5 (from versions: none)
# ERROR: No matching distribution found for pickle5
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## Task 2: Model Metadata (30 points)
#
# Create model metadata:
# 1. Model version
# 2. Training info
# 3. Performance metrics

# %%
# TODO: Create metadata
# YOUR CODE HERE

# %% [markdown]
# ## Task 3: Distribution Package (30 points)
#
# Create distribution package.
#
# **Submission**: Complete notebook with packaged model.
#
# **Grading**: 100 points total
