# %% [markdown]
# # Exercise: Package Model for Distribution
# ## AIAT 125 - Model Deployment
#
# ## Learning Objectives
#
# - Package models in different formats
# - Create model artifacts
# - Prepare for distribution
# - Apply to production deployment
#
# ## Real-World Context
#
# Package trained model for sharing and deployment.
#
# **Task**: Package model in multiple formats.
#
# ---
#
# ## Task 1: Model Packaging (40 points)
#
# Package model:
# 1. Save as Pickle
# 2. Save as ONNX
# 3. Save as SavedModel

# %%
# %pip install pickle5 onnx scikit-learn -q
import pickle
import joblib

# TODO: Load trained model
# YOUR CODE HERE

# TODO: Package in different formats
# YOUR CODE HERE
# Out:
#   error: subprocess-exited-with-error
#
#   × Building wheel for pickle5 (pyproject.toml) did not run successfully.
#   │ exit code: 1
#   ╰─> [103 lines of output]
#       /private/var/folders/7n/l2c2z2x57871xg4f_0drsv1m0000gn/T/pip-build-env-7zqg_xov/overlay/lib/python3.13/site-packages/setuptools/dist.py:759: SetuptoolsDeprecationWarning: License classifiers are deprecated.
#       !!
#
#               ********************************************************************************
#               Please consider removing the following classifiers in favor of a SPDX license expression:
#
#               License :: OSI Approved :: Python Software Foundation License
#
#               See https://packaging.python.org/en/latest/guides/writing-pyproject-toml/#license for details.
#               ********************************************************************************
#
#       !!
#         self._finalize_license_expression()
#       running bdist_wheel
#       running build
# ...

# %% [markdown]
# ## Task 2: Model Metadata (30 points)
#
# Create model metadata:
# 1. Model version
# 2. Training info
# 3. Performance metrics

# %%
# TODO: Create metadata
# YOUR CODE HERE

# %% [markdown]
# ## Task 3: Distribution Package (30 points)
#
# Create distribution package.
#
# **Submission**: Complete notebook with packaged model.
#
# **Grading**: 100 points total
