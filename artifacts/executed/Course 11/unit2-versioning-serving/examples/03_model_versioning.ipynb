# %% [markdown]
# # Model Versioning with MLflow
#
# ## 📚 Learning Objectives
#
# By completing this notebook, you will:
# - Understand the key concepts of this topic
# - Apply the topic using Python code examples
# - Practice with small, realistic datasets or scenarios
#
# ## 🔗 Prerequisites
#
# - ✅ Basic Python
# - ✅ Basic NumPy/Pandas (when applicable)
#
# ---
#
# ## Official Structure Reference
#
# This notebook supports **Course 11, Unit 2** requirements from `DETAILED_UNIT_DESCRIPTIONS.md`.
#
# ---

# %% [markdown]
# # Model Versioning with MLflow
# ## AIAT 125 - Model Deployment
#
# ## Learning Objectives
#
# - Understand model versioning
# - Use MLflow for model registry
# - Track model versions
# - Manage model lifecycle
#
# ## Real-World Context
#
# Model management, tracking, and version control in production.
#
# **Industry Impact**: Essential for production ML systems.

# %%
# %pip install mlflow -q
import mlflow
import mlflow.sklearn
print('✅ Setup complete!')
# Out:
# WARNING: Retrying (Retry(total=4, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<pip._vendor.urllib3.connection.HTTPSConnection object at 0x10503b8c0>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known')': /simple/protobuf/
# WARNING: Retrying (Retry(total=3, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<pip._vendor.urllib3.connection.HTTPSConnection object at 0x105282490>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known')': /simple/protobuf/
# WARNING: Retrying (Retry(total=2, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<pip._vendor.urllib3.connection.HTTPSConnection object at 0x105282710>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known')': /simple/protobuf/
# WARNING: Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<pip._vendor.urllib3.connection.HTTPSConnection object at 0x105282990>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known')': /simple/protobuf/
# WARNING: Retrying (Retry(total=0, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<pip._vendor.urllib3.connection.HTTPSConnection object at 0x105282c10>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known')': /simple/protobuf/
# WARNING: Retrying (Retry(total=4, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<pip._vendor.urllib3.connection.HTTPSConnection object at 0x1052820d0>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known')': /simple/opentelemetry-proto/
# WARNING: Retrying (Retry(total=3, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<pip._vendor.urllib3.connection.HTTPSConnection object at 0x105282d50>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known')': /simple/opentelemetry-proto/
# WARNING: Retrying (Retry(total=2, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<pip._vendor.urllib3.connection.HTTPSConnection object at 0x105282ad0>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known')': /simple/opentelemetry-proto/
# WARNING: Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<pip._vendor.urllib3.connection.HTTPSConnection object at 0x105282850>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known')': /simple/opentelemetry-proto/
# WARNING: Retrying (Retry(total=0, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<pip._vendor.urllib3.connection.HTTPSConnection object at 0x1052825d0>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known')': /simple/opentelemetry-proto/
# WARNING: Retrying (Retry(total=4, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<pip._vendor.urllib3.connection.HTTPSConnection object at 0x105283750>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known')': /simple/databricks-sdk/
# WARNING: Retrying (Retry(total=3, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<pip._vendor.urllib3.connection.HTTPSConnection object at 0x1052839d0>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known')': /simple/databricks-sdk/
# WARNING: Retrying (Retry(total=2, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<pip._vendor.urllib3.connection.HTTPSConnection object at 0x105283c50>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known')': /simple/databricks-sdk/
# WARNING: Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<pip._vendor.urllib3.connection.HTTPSConnection object at 0x105283ed0>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known')': /simple/databricks-sdk/
# WARNING: Retrying (Retry(total=0, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<pip._vendor.urllib3.connection.HTTPSConnection object at 0x105354190>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known')': /simple/databricks-sdk/
# WARNING: Retrying (Retry(total=4, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<pip._vendor.urllib3.connection.HTTPSConnection object at 0x105354910>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known')': /simple/mlflow-tracing/
# WARNING: Retrying (Retry(total=3, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<pip._vendor.urllib3.connection.HTTPSConnection object at 0x105354cd0>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known')': /simple/mlflow-tracing/
# WARNING: Retrying (Retry(total=2, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<pip._vendor.urllib3.connection.HTTPSConnection object at 0x105354f50>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known')': /simple/mlflow-tracing/
# WARNING: Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<pip._vendor.urllib3.connection.HTTPSConnection object at 0x1052834d0>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known')': /simple/mlflow-tracing/
# WARNING: Retrying (Retry(total=0, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<pip._vendor.urllib3.connection.HTTPSConnection object at 0x105283610>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known')': /simple/mlflow-tracing/
# WARNING: Retrying (Retry(total=4, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<pip._vendor.urllib3.connection.HTTPSConnection object at 0x105283c50>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known')': /simple/mlflow-skinny/
# WARNING: Retrying (Retry(total=3, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<pip._vendor.urllib3.connection.HTTPSConnection object at 0x105283750>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known')': /simple/mlflow-skinny/
# WARNING: Retrying (Retry(total=2, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<pip._vendor.urllib3.connection.HTTPSConnection object at 0x105281a90>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known')': /simple/mlflow-skinny/
# WARNING: Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<pip._vendor.urllib3.connection.HTTPSConnection object at 0x105281950>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known')': /simple/mlflow-skinny/
# WARNING: Retrying (Retry(total=0, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<pip._vendor.urllib3.connection.HTTPSConnection object at 0x105283110>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known')': /simple/mlflow-skinny/
# WARNING: Retrying (Retry(total=4, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<pip._vendor.urllib3.connection.HTTPSConnection object at 0x105283250>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known')': /simple/mlflow/
# WARNING: Retrying (Retry(total=3, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<pip._vendor.urllib3.connection.HTTPSConnection object at 0x105282490>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known')': /simple/mlflow/
# WARNING: Retrying (Retry(total=2, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<pip._vendor.urllib3.connection.HTTPSConnection object at 0x105282710>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known')': /simple/mlflow/
# WARNING: Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<pip._vendor.urllib3.connection.HTTPSConnection object at 0x105282990>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known')': /simple/mlflow/
# WARNING: Retrying (Retry(total=0, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<pip._vendor.urllib3.connection.HTTPSConnection object at 0x105282c10>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known')': /simple/mlflow/
# WARNING: Retrying (Retry(total=4, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<pip._vendor.urllib3.connection.HTTPSConnection object at 0x1053551d0>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known')': /simple/opentelemetry-api/
# WARNING: Retrying (Retry(total=3, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<pip._vendor.urllib3.connection.HTTPSConnection object at 0x105355450>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known')': /simple/opentelemetry-api/
# WARNING: Retrying (Retry(total=2, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<pip._vendor.urllib3.connection.HTTPSConnection object at 0x1053556d0>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known')': /simple/opentelemetry-api/
# WARNING: Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<pip._vendor.urllib3.connection.HTTPSConnection object at 0x105355950>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known')': /simple/opentelemetry-api/
# WARNING: Retrying (Retry(total=0, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<pip._vendor.urllib3.connection.HTTPSConnection object at 0x105355bd0>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known')': /simple/opentelemetry-api/
# WARNING: Retrying (Retry(total=4, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<pip._vendor.urllib3.connection.HTTPSConnection object at 0x105281590>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known')': /simple/matplotlib/
# WARNING: Retrying (Retry(total=3, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<pip._vendor.urllib3.connection.HTTPSConnection object at 0x105355e50>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known')': /simple/matplotlib/
# WARNING: Retrying (Retry(total=2, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<pip._vendor.urllib3.connection.HTTPSConnection object at 0x105356350>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known')': /simple/matplotlib/
# WARNING: Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<pip._vendor.urllib3.connection.HTTPSConnection object at 0x1053565d0>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known')': /simple/matplotlib/
# WARNING: Retrying (Retry(total=0, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<pip._vendor.urllib3.connection.HTTPSConnection object at 0x105356850>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known')': /simple/matplotlib/
# WARNING: Retrying (Retry(total=4, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<pip._vendor.urllib3.connection.HTTPSConnection object at 0x1051bb9d0>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known')': /simple/importlib-metadata/
# WARNING: Retrying (Retry(total=3, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<pip._vendor.urllib3.connection.HTTPSConnection object at 0x105280b90>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known')': /simple/importlib-metadata/
# WARNING: Retrying (Retry(total=2, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<pip._vendor.urllib3.connection.HTTPSConnection object at 0x105280410>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known')': /simple/importlib-metadata/
# WARNING: Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<pip._vendor.urllib3.connection.HTTPSConnection object at 0x105281090>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known')': /simple/importlib-metadata/
# WARNING: Retrying (Retry(total=0, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<pip._vendor.urllib3.connection.HTTPSConnection object at 0x105356ad0>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known')': /simple/importlib-metadata/
# WARNING: Retrying (Retry(total=4, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<pip._vendor.urllib3.connection.HTTPSConnection object at 0x105281090>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known')': /simple/huey/
# WARNING: Retrying (Retry(total=3, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<pip._vendor.urllib3.connection.HTTPSConnection object at 0x105280410>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known')': /simple/huey/
# WARNING: Retrying (Retry(total=2, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<pip._vendor.urllib3.connection.HTTPSConnection object at 0x105280b90>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known')': /simple/huey/
# WARNING: Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<pip._vendor.urllib3.connection.HTTPSConnection object at 0x105280e10>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known')': /simple/huey/
# WARNING: Retrying (Retry(total=0, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<pip._vendor.urllib3.connection.HTTPSConnection object at 0x105282c10>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known')': /simple/huey/
# WARNING: Retrying (Retry(total=4, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<pip._vendor.urllib3.connection.HTTPSConnection object at 0x1052820d0>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known')': /simple/gunicorn/
# WARNING: Retrying (Retry(total=3, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<pip._vendor.urllib3.connection.HTTPSConnection object at 0x105282ad0>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known')': /simple/gunicorn/
# WARNING: Retrying (Retry(total=2, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<pip._vendor.urllib3.connection.HTTPSConnection object at 0x1052825d0>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known')': /simple/gunicorn/
# WARNING: Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<pip._vendor.urllib3.connection.HTTPSConnection object at 0x105282850>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known')': /simple/gunicorn/
# WARNING: Retrying (Retry(total=0, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<pip._vendor.urllib3.connection.HTTPSConnection object at 0x105281bd0>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known')': /simple/gunicorn/
# WARNING: Retrying (Retry(total=4, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<pip._vendor.urllib3.connection.HTTPSConnection object at 0x105282e90>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known')': /simple/graphql-relay/
# WARNING: Retrying (Retry(total=3, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<pip._vendor.urllib3.connection.HTTPSConnection object at 0x105283890>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known')': /simple/graphql-relay/
# WARNING: Retrying (Retry(total=2, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<pip._vendor.urllib3.connection.HTTPSConnection object at 0x105283b10>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known')': /simple/graphql-relay/
# WARNING: Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<pip._vendor.urllib3.connection.HTTPSConnection object at 0x105283610>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known')': /simple/graphql-relay/
# WARNING: Retrying (Retry(total=0, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<pip._vendor.urllib3.connection.HTTPSConnection object at 0x1052834d0>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known')': /simple/graphql-relay/
# WARNING: Retrying (Retry(total=4, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<pip._vendor.urllib3.connection.HTTPSConnection object at 0x1051bb890>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known')': /simple/graphql-core/
# WARNING: Retrying (Retry(total=3, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<pip._vendor.urllib3.connection.HTTPSConnection object at 0x105357390>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known')': /simple/graphql-core/
# WARNING: Retrying (Retry(total=2, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<pip._vendor.urllib3.connection.HTTPSConnection object at 0x105356c10>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known')': /simple/graphql-core/
# WARNING: Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<pip._vendor.urllib3.connection.HTTPSConnection object at 0x105356e90>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known')': /simple/graphql-core/
# WARNING: Retrying (Retry(total=0, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<pip._vendor.urllib3.connection.HTTPSConnection object at 0x105356990>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known')': /simple/graphql-core/
# WARNING: Retrying (Retry(total=4, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<pip._vendor.urllib3.connection.HTTPSConnection object at 0x105356710>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known')': /simple/graphene/
# WARNING: Retrying (Retry(total=3, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<pip._vendor.urllib3.connection.HTTPSConnection object at 0x105355f90>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known')': /simple/graphene/
# WARNING: Retrying (Retry(total=2, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<pip._vendor.urllib3.connection.HTTPSConnection object at 0x1053560d0>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known')': /simple/graphene/
# WARNING: Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<pip._vendor.urllib3.connection.HTTPSConnection object at 0x105355bd0>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known')': /simple/graphene/
# WARNING: Retrying (Retry(total=0, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<pip._vendor.urllib3.connection.HTTPSConnection object at 0x105355950>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known')': /simple/graphene/
# WARNING: Retrying (Retry(total=4, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<pip._vendor.urllib3.connection.HTTPSConnection object at 0x1051bb390>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known')': /simple/google-auth/
# WARNING: Retrying (Retry(total=3, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<pip._vendor.urllib3.connection.HTTPSConnection object at 0x1053556d0>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known')': /simple/google-auth/
# WARNING: Retrying (Retry(total=2, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<pip._vendor.urllib3.connection.HTTPSConnection object at 0x1053551d0>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known')': /simple/google-auth/
# WARNING: Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<pip._vendor.urllib3.connection.HTTPSConnection object at 0x105354190>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known')': /simple/google-auth/
# WARNING: Retrying (Retry(total=0, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<pip._vendor.urllib3.connection.HTTPSConnection object at 0x105354690>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known')': /simple/google-auth/
# WARNING: Retrying (Retry(total=4, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<pip._vendor.urllib3.connection.HTTPSConnection object at 0x1051bad50>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known')': /simple/gitdb/
# WARNING: Retrying (Retry(total=3, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<pip._vendor.urllib3.connection.HTTPSConnection object at 0x105357110>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known')': /simple/gitdb/
# WARNING: Retrying (Retry(total=2, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<pip._vendor.urllib3.connection.HTTPSConnection object at 0x1051bb390>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known')': /simple/gitdb/
# WARNING: Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<pip._vendor.urllib3.connection.HTTPSConnection object at 0x1051bb890>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known')': /simple/gitdb/
# WARNING: Retrying (Retry(total=0, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<pip._vendor.urllib3.connection.HTTPSConnection object at 0x1051bbc50>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known')': /simple/gitdb/
# WARNING: Retrying (Retry(total=4, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<pip._vendor.urllib3.connection.HTTPSConnection object at 0x1051ba490>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known')': /simple/gitpython/
# WARNING: Retrying (Retry(total=3, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<pip._vendor.urllib3.connection.HTTPSConnection object at 0x105283610>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known')': /simple/gitpython/
# WARNING: Retrying (Retry(total=2, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<pip._vendor.urllib3.connection.HTTPSConnection object at 0x105283890>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known')': /simple/gitpython/
# WARNING: Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<pip._vendor.urllib3.connection.HTTPSConnection object at 0x105282e90>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known')': /simple/gitpython/
# WARNING: Retrying (Retry(total=0, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<pip._vendor.urllib3.connection.HTTPSConnection object at 0x105282fd0>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known')': /simple/gitpython/
# WARNING: Retrying (Retry(total=4, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<pip._vendor.urllib3.connection.HTTPSConnection object at 0x105281bd0>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known')': /simple/flask-cors/
# WARNING: Retrying (Retry(total=3, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<pip._vendor.urllib3.connection.HTTPSConnection object at 0x1052825d0>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known')': /simple/flask-cors/
# WARNING: Retrying (Retry(total=2, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<pip._vendor.urllib3.connection.HTTPSConnection object at 0x105282ad0>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known')': /simple/flask-cors/
# WARNING: Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<pip._vendor.urllib3.connection.HTTPSConnection object at 0x1052820d0>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known')': /simple/flask-cors/
# WARNING: Retrying (Retry(total=0, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<pip._vendor.urllib3.connection.HTTPSConnection object at 0x105282d50>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known')': /simple/flask-cors/
# WARNING: Retrying (Retry(total=4, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<pip._vendor.urllib3.connection.HTTPSConnection object at 0x1051ba350>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known')': /simple/flask/
# WARNING: Retrying (Retry(total=3, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<pip._vendor.urllib3.connection.HTTPSConnection object at 0x105282990>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known')': /simple/flask/
# WARNING: Retrying (Retry(total=2, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<pip._vendor.urllib3.connection.HTTPSConnection object at 0x105280690>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known')': /simple/flask/
# WARNING: Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<pip._vendor.urllib3.connection.HTTPSConnection object at 0x105280190>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known')': /simple/flask/
# WARNING: Retrying (Retry(total=0, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<pip._vendor.urllib3.connection.HTTPSConnection object at 0x105280a50>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known')': /simple/flask/
# WARNING: Retrying (Retry(total=4, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<pip._vendor.urllib3.connection.HTTPSConnection object at 0x1051b9e50>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known')': /simple/fastapi/
# WARNING: Retrying (Retry(total=3, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<pip._vendor.urllib3.connection.HTTPSConnection object at 0x1051b9810>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known')': /simple/fastapi/
# WARNING: Retrying (Retry(total=2, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<pip._vendor.urllib3.connection.HTTPSConnection object at 0x105357750>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known')': /simple/fastapi/
# WARNING: Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<pip._vendor.urllib3.connection.HTTPSConnection object at 0x1053542d0>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known')': /simple/fastapi/
# WARNING: Retrying (Retry(total=0, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<pip._vendor.urllib3.connection.HTTPSConnection object at 0x105355310>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known')': /simple/fastapi/
# WARNING: Retrying (Retry(total=4, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<pip._vendor.urllib3.connection.HTTPSConnection object at 0x1051b91d0>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known')': /simple/docker/
# WARNING: Retrying (Retry(total=3, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<pip._vendor.urllib3.connection.HTTPSConnection object at 0x1051b9090>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known')': /simple/docker/
# WARNING: Retrying (Retry(total=2, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<pip._vendor.urllib3.connection.HTTPSConnection object at 0x105355810>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known')': /simple/docker/
# WARNING: Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<pip._vendor.urllib3.connection.HTTPSConnection object at 0x105355a90>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known')': /simple/docker/
# WARNING: Retrying (Retry(total=0, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<pip._vendor.urllib3.connection.HTTPSConnection object at 0x105355d10>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known')': /simple/docker/
# WARNING: Retrying (Retry(total=4, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<pip._vendor.urllib3.connection.HTTPSConnection object at 0x1051b8a50>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known')': /simple/cryptography/
# WARNING: Retrying (Retry(total=3, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<pip._vendor.urllib3.connection.HTTPSConnection object at 0x105356210>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known')': /simple/cryptography/
# WARNING: Retrying (Retry(total=2, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<pip._vendor.urllib3.connection.HTTPSConnection object at 0x105356350>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known')': /simple/cryptography/
# WARNING: Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<pip._vendor.urllib3.connection.HTTPSConnection object at 0x105355e50>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known')': /simple/cryptography/
# WARNING: Retrying (Retry(total=0, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<pip._vendor.urllib3.connection.HTTPSConnection object at 0x1053565d0>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known')': /simple/cryptography/
# WARNING: Retrying (Retry(total=4, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<pip._vendor.urllib3.connection.HTTPSConnection object at 0x105356850>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known')': /simple/cloudpickle/
# WARNING: Retrying (Retry(total=3, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<pip._vendor.urllib3.connection.HTTPSConnection object at 0x105356ad0>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known')': /simple/cloudpickle/
# WARNING: Retrying (Retry(total=2, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<pip._vendor.urllib3.connection.HTTPSConnection object at 0x105357890>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known')': /simple/cloudpickle/
# WARNING: Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<pip._vendor.urllib3.connection.HTTPSConnection object at 0x105357b10>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known')': /simple/cloudpickle/
# WARNING: Retrying (Retry(total=0, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<pip._vendor.urllib3.connection.HTTPSConnection object at 0x105357d90>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known')': /simple/cloudpickle/
# WARNING: Retrying (Retry(total=4, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<pip._vendor.urllib3.connection.HTTPSConnection object at 0x105187c50>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known')': /simple/click/
# WARNING: Retrying (Retry(total=3, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<pip._vendor.urllib3.connection.HTTPSConnection object at 0x105357ed0>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known')': /simple/click/
# WARNING: Retrying (Retry(total=2, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<pip._vendor.urllib3.connection.HTTPSConnection object at 0x105357c50>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known')': /simple/click/
# WARNING: Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<pip._vendor.urllib3.connection.HTTPSConnection object at 0x1053579d0>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known')': /simple/click/
# WARNING: Retrying (Retry(total=0, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<pip._vendor.urllib3.connection.HTTPSConnection object at 0x105357250>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known')': /simple/click/
# WARNING: Retrying (Retry(total=4, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<pip._vendor.urllib3.connection.HTTPSConnection object at 0x105356d50>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known')': /simple/cachetools/
# WARNING: Retrying (Retry(total=3, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<pip._vendor.urllib3.connection.HTTPSConnection object at 0x105355e50>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known')': /simple/cachetools/
# WARNING: Retrying (Retry(total=2, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<pip._vendor.urllib3.connection.HTTPSConnection object at 0x105356350>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known')': /simple/cachetools/
# WARNING: Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<pip._vendor.urllib3.connection.HTTPSConnection object at 0x105356210>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known')': /simple/cachetools/
# WARNING: Retrying (Retry(total=0, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<pip._vendor.urllib3.connection.HTTPSConnection object at 0x105354410>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known')': /simple/cachetools/
# WARNING: Retrying (Retry(total=4, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<pip._vendor.urllib3.connection.HTTPSConnection object at 0x1053560d0>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known')': /simple/alembic/
# WARNING: Retrying (Retry(total=3, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<pip._vendor.urllib3.connection.HTTPSConnection object at 0x105355450>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known')': /simple/alembic/
# WARNING: Retrying (Retry(total=2, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<pip._vendor.urllib3.connection.HTTPSConnection object at 0x105355950>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known')': /simple/alembic/
# WARNING: Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<pip._vendor.urllib3.connection.HTTPSConnection object at 0x1053556d0>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known')': /simple/alembic/
# WARNING: Retrying (Retry(total=0, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<pip._vendor.urllib3.connection.HTTPSConnection object at 0x1053551d0>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known')': /simple/alembic/
# ERROR: Cannot install databricks-sdk==0.78.0, mlflow-skinny==3.8.1, mlflow-tracing==3.8.1 and opentelemetry-proto==1.27.0 because these package versions have conflicting dependencies.
# ERROR: ResolutionImpossible: for help visit https://pip.pypa.io/en/latest/topics/dependency-resolution/#dealing-with-dependency-conflicts
# Note: you may need to restart the kernel to use updated packages.
# ✅ Setup complete!

# %% [markdown]
# ## Part 1: MLflow Setup

# %%
# Set MLflow tracking URI (use local file to avoid connection timeout)
mlflow.set_tracking_uri('file:./mlruns')  # Local file instead of server

# Start experiment
mlflow.set_experiment('model_versioning_demo')
print('✅ MLflow setup complete')
# Out:
# ✅ MLflow setup complete
# /opt/anaconda3/lib/python3.13/site-packages/mlflow/tracking/_tracking_service/utils.py:178: FutureWarning: The filesystem tracking backend (e.g., './mlruns') will be deprecated in February 2026. Consider transitioning to a database backend (e.g., 'sqlite:///mlflow.db') to take advantage of the latest MLflow features. See https://github.com/mlflow/mlflow/issues/18534 for more details and migration guidance. For migrating existing data, https://github.com/mlflow/mlflow-export-import can be used.
#   return FileStore(store_uri, store_uri)

# %% [markdown]
# ## Part 2: Logging Models

# %%
# Example: Log model with MLflow
with mlflow.start_run():
    # Log parameters
    mlflow.log_param('n_estimators', 100)
    mlflow.log_param('max_depth', 10)
    
    # Log metrics
    mlflow.log_metric('accuracy', 0.95)
    mlflow.log_metric('f1_score', 0.93)
 
 # Log model
 # mlflow.sklearn.log_model(model, 'model')
print('✅ Model logged to MLflow')
print('\nReal-world: Track all model versions and experiments')
# Out:
# ✅ Model logged to MLflow
#
# Real-world: Track all model versions and experiments

# %% [markdown]
# ## Part 3: Model Registry

# %%
print('📝 Model Registry Concept:')
print('\n1. Register models with versions')
print('2. Tag models (production, staging, development)')
print('3. Track model lineage')
print('4. Manage model lifecycle')
print('\n✅ Model registry understood!')
print('\nReal-world: Production model management')
# Out:
# 📝 Model Registry Concept:
#
# 1. Register models with versions
# 2. Tag models (production, staging, development)
# 3. Track model lineage
# 4. Manage model lifecycle
#
# ✅ Model registry understood!
#
# Real-world: Production model management

# %% [markdown]
# ## Real-World Applications
#
# - **Production**: Track deployed models
# - **Experiments**: Compare model versions
# - **Compliance**: Audit model changes
# - **Collaboration**: Share models across teams
#
# ---
#
# **End of Notebook**
