# %% [markdown]
# # Exercise 01: Generative AI Ethics
# ## AIAT 124 - Generative AI
#
# ---
#
# ## Learning Objectives
#
# In this exercise, you will:
# - Detect bias in generative models
# - Implement deepfake detection
# - Create ethical guidelines
# - Evaluate responsible AI practices
#
# ---
#
# ## Real-World Context
#
# You are auditing a generative AI system for ethical concerns, including bias detection and deepfake identification.
#
# ---

# %%
# Setup
# TODO: Install required libraries
# %pip install ...

# TODO: Import libraries
# YOUR CODE HERE

print('✅ Setup complete!')
# Out:
# ✅ Setup complete!

# %% [markdown]
# ## Task 1: Bias Detection (35 points)
#
# Detect and analyze bias in generative model outputs.
#
# **Requirements:**
# - Analyze generated samples
# - Identify bias patterns
# - Measure bias metrics
# - Document findings

# %%
# TODO: Implement solution
# YOUR CODE HERE

# %% [markdown]
# ## Task 2: Deepfake Detection (35 points)
#
# Implement or use deepfake detection techniques.
#
# **Requirements:**
# - Set up detection system
# - Test on samples
# - Evaluate accuracy
# - Document limitations

# %%
# TODO: Implement solution
# YOUR CODE HERE

# %% [markdown]
# ## Task 3: Ethical Guidelines (30 points)
#
# Create comprehensive ethical guidelines for generative AI deployment.
#
# **Requirements:**
# - Document ethical concerns
# - Create guidelines
# - Propose mitigation strategies
# - Include best practices

# %%
# TODO: Implement solution
# YOUR CODE HERE

# %% [markdown]
# ---
#
# ## Submission
#
# **Submission**: Complete notebook with all tasks implemented
#
# **Grading**: 100 points total
