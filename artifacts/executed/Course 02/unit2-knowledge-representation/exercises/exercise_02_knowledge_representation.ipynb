# %% [markdown]
# # Exercise 02: Knowledge Representation
# ## AIAT 112
#
# ---
#
# ## Learning Objectives
#
# In this exercise, you will:
# - Apply Knowledge Representation concepts
# - Solve real-world problems
#
# ---
#
# ## Real-World Context
#
# Real-world application of Knowledge Representation
#
# ---

# %%
# Setup
# TODO: Import required libraries
# YOUR CODE HERE

# %% [markdown]
# ## Task 1: Implementation (50 points)
#
# Implement Knowledge Representation solution
#
# **Requirements:**
# - Use Python
# - Follow best practices

# %%
# TODO: Implement solution
# YOUR CODE HERE

# %% [markdown]
# ## Task 2: Evaluation (30 points)
#
# Evaluate solution
#
# **Requirements:**
# - Test with real data
# - Measure performance

# %%
# TODO: Implement solution
# YOUR CODE HERE

# %% [markdown]
# ## Task 3: Analysis (20 points)
#
# Analyze results
#
# **Requirements:**
# - Document findings
# - Provide insights

# %%
# TODO: Implement solution
# YOUR CODE HERE
