# %% [markdown]
# # Cleaning and Preparing Data for ML Tasks
#
# ## 📚 Learning Objectives
#
# By completing this notebook, you will:
# - Clean data for ML
# - Handle missing values
# - Encode categorical variables
# - Prepare features
# - Split data
#
# ## 🔗 Prerequisites
#
# - ✅ Understanding of data cleaning
# - ✅ Understanding of ML preprocessing
# - ✅ Scikit-learn knowledge
#
# ---
#
# ## Official Structure Reference
#
# This notebook covers practical activities from **Course 05, Unit 4**:
# - Cleaning and preparing data for ML tasks (handling missing values, encoding categorical variables)
# - **Source:** `DETAILED_UNIT_DESCRIPTIONS.md` - Unit 4 Practical Content
#
# ---
#
# ## Introduction
#
# **Data preparation for ML** involves cleaning data, handling missing values, encoding categorical variables, and preparing features for machine learning models.

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import LabelEncoder, OneHotEncoder
from sklearn.model_selection import train_test_split

print("✅ Libraries imported!")
print("\nData Preparation for ML Tasks")
print("=" * 60)

print("\nMissing Values:")
print("  - Detection: isnull(), info()")
print("  - Removal: dropna()")
print("  - Imputation: fillna(), SimpleImputer")
print("  - Forward/backward fill")

print("\nCategorical Encoding:")
print("  - Label Encoding")
print("  - One-Hot Encoding")
print("  - Ordinal Encoding")
print("  - Target Encoding")

print("\nData Splitting:")
print("  - Train/Test split")
print("  - Train/Validation/Test")
print("  - Stratified splitting")
print("  - Time-based splitting")

print("\n✅ Data preparation concepts understood!")
# Out:
# ✅ Libraries imported!
#
# Data Preparation for ML Tasks
# ...
#
# Missing Values:
#   - Detection: isnull(), info()
#   - Removal: dropna()
#   - Imputation: fillna(), SimpleImputer
#   - Forward/backward fill
#
# Categorical Encoding:
#   - Label Encoding
#   - One-Hot Encoding
#   - Ordinal Encoding
#   - Target Encoding
#
# Data Splitting:
#   - Train/Test split
#   - Train/Validation/Test
#   - Stratified splitting
#   - Time-based splitting
#
# ✅ Data preparation concepts understood!
