# %% [markdown]
# # Creating Various Chart Types Using Matplotlib and Seaborn
#
# ## 📚 Learning Objectives
#
# By completing this notebook, you will:
# - Create various chart types
# - Use Matplotlib for plotting
# - Use Seaborn for statistical plots
# - Choose appropriate visualizations
# - Customize charts
#
# ## 🔗 Prerequisites
#
# - ✅ Understanding of data visualization
# - ✅ Matplotlib knowledge
# - ✅ Seaborn knowledge
#
# ---
#
# ## Official Structure Reference
#
# This notebook covers practical activities from **Course 05, Unit 3**:
# - Creating various chart types using Matplotlib and Seaborn
# - **Source:** `DETAILED_UNIT_DESCRIPTIONS.md` - Unit 3 Practical Content
#
# ---
#
# ## Introduction
#
# **Matplotlib and Seaborn** provide comprehensive tools for creating various chart types, enabling effective data visualization and communication.

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np_
print("✅ Libraries imported!")
print("\nChart Types: Matplotlib and Seaborn")
print("=" * 60)

print("\nMatplotlib Charts:")
print("  - Line plots")
print("  - Bar charts")
print("  - Scatter plots")
print("  - Histograms")
print("  - Pie charts")

print("\nSeaborn Charts:")
print("  - Distribution plots")
print("  - Categorical plots")
print("  - Regression plots")
print("  - Heatmaps")
print("  - Pair plots")

print("\nChart Selection:")
print("  - Distribution: Histogram, KDE")
print("  - Relationships: Scatter, Line")
print("  - Comparisons: Bar, Box")
print("  - Composition: Pie, Stacked")

print("\n✅ Chart types concepts understood!")
# Out:
# ✅ Libraries imported!
#
# Chart Types: Matplotlib and Seaborn
# ...
#
# Matplotlib Charts:
#   - Line plots
#   - Bar charts
#   - Scatter plots
#   - Histograms
#   - Pie charts
#
# Seaborn Charts:
#   - Distribution plots
#   - Categorical plots
#   - Regression plots
#   - Heatmaps
#   - Pair plots
#
# Chart Selection:
#   - Distribution: Histogram, KDE
#   - Relationships: Scatter, Line
#   - Comparisons: Bar, Box
#   - Composition: Pie, Stacked
#
# ✅ Chart types concepts understood!

# %% [markdown]
# # Creating Various Chart Types Using Matplotlib and Seaborn
#
# ## 📚 Learning Objectives
#
# By completing this notebook, you will:
# - Create various chart types
# - Use Matplotlib for plotting
# - Use Seaborn for statistical visualization
# - Choose appropriate charts
# - Customize visualizations
#
# ## 🔗 Prerequisites
#
# - ✅ Understanding of data visualization
# - ✅ Matplotlib knowledge
# - ✅ Seaborn knowledge
#
# ---
#
# ## Official Structure Reference
#
# This notebook covers practical activities from **Course 05, Unit 3**:
# - Creating various chart types using Matplotlib and Seaborn
# - **Source:** `DETAILED_UNIT_DESCRIPTIONS.md` - Unit 3 Practical Content
#
# ---
#
# ## Introduction
#
# **Matplotlib and Seaborn** provide comprehensive tools for creating various chart types, enabling effective data visualization and communication.

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np_
print("✅ Libraries imported!")
print("\nChart Types: Matplotlib and Seaborn")
print("=" * 60)

print("\nMatplotlib Charts:")
print("  - Line plots")
print("  - Bar charts")
print("  - Scatter plots")
print("  - Histograms")
print("  - Pie charts")

print("\nSeaborn Charts:")
print("  - Distribution plots")
print("  - Categorical plots")
print("  - Regression plots")
print("  - Heatmaps")
print("  - Pair plots")

print("\nChart Selection:")
print("  - Distribution: Histogram, KDE")
print("  - Relationships: Scatter, Line")
print("  - Comparisons: Bar, Box")
print("  - Composition: Pie, Stacked")

print("\n✅ Chart types concepts understood!")
# Out:
# ✅ Libraries imported!
#
# Chart Types: Matplotlib and Seaborn
# ...
#
# Matplotlib Charts:
#   - Line plots
#   - Bar charts
#   - Scatter plots
#   - Histograms
#   - Pie charts
#
# Seaborn Charts:
#   - Distribution plots
#   - Categorical plots
#   - Regression plots
#   - Heatmaps
#   - Pair plots
#
# Chart Selection:
#   - Distribution: Histogram, KDE
#   - Relationships: Scatter, Line
#   - Comparisons: Bar, Box
#   - Composition: Pie, Stacked
#
# ✅ Chart types concepts understood!
