# %% [markdown]
# # Feature Transformation: Scaling and Encoding
#
# ## 📚 Learning Objectives
#
# By completing this notebook, you will:
# - Transform features (scaling, encoding)
# - Scale numerical features
# - Encode categorical variables
# - Prepare data for analysis
# - Apply transformations
#
# ## 🔗 Prerequisites
#
# - ✅ Understanding of feature engineering
# - ✅ Scikit-learn knowledge
# - ✅ Pandas knowledge
#
# ---
#
# ## Official Structure Reference
#
# This notebook covers practical activities from **Course 05, Unit 2**:
# - Feature Transformation: Transforming data (e.g., scaling, encoding) to prepare it for analysis
# - **Source:** `DETAILED_UNIT_DESCRIPTIONS.md` - Unit 2 Practical Content
#
# ---
#
# ## Introduction
#
# **Feature transformation** prepares data for analysis by scaling numerical features and encoding categorical variables, essential for machine learning.

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler, MinMaxScaler, LabelEncoder, OneHotEncoder

print("✅ Libraries imported!")
print("\nFeature Transformation: Scaling and Encoding")
print("=" * 60)

print("\nScaling:")
print("  - StandardScaler: Mean 0, std 1")
print("  - MinMaxScaler: Range [0, 1]")
print("  - RobustScaler: Median and IQR")
print("  - Normalization")

print("\nEncoding:")
print("  - Label Encoding: Ordinal categories")
print("  - One-Hot Encoding: Nominal categories")
print("  - Target Encoding: Mean target")
print("  - Frequency Encoding")

print("\nWhen to Use:")
print("  - Scaling: Numerical features")
print("  - Encoding: Categorical features")
print("  - Before ML models")
print("  - For distance-based algorithms")

print("\n✅ Feature transformation concepts understood!")
# Out:
# ✅ Libraries imported!
#
# Feature Transformation: Scaling and Encoding
# ============================================================
#
# Scaling:
#   - StandardScaler: Mean 0, std 1
#   - MinMaxScaler: Range [0, 1]
#   - RobustScaler: Median and IQR
#   - Normalization
#
# Encoding:
#   - Label Encoding: Ordinal categories
#   - One-Hot Encoding: Nominal categories
#   - Target Encoding: Mean target
#   - Frequency Encoding
#
# When to Use:
#   - Scaling: Numerical features
#   - Encoding: Categorical features
#   - Before ML models
#   - For distance-based algorithms
#
# ✅ Feature transformation concepts understood!
