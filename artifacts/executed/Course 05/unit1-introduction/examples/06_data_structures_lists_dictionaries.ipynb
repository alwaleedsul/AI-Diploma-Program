# %% [markdown]
# # Working with Data Structures: Lists and Dictionaries
#
# ## 📚 Learning Objectives
#
# By completing this notebook, you will:
# - Work with lists (indexing, slicing)
# - Work with dictionaries
# - Transform data structures
# - Apply data manipulation
# - Use common operations
#
# ## 🔗 Prerequisites
#
# - ✅ Python programming basics
# - ✅ Understanding of data structures
#
# ---
#
# ## Official Structure Reference
#
# This notebook covers practical activities from **Course 05, Unit 1**:
# - Working with Data Structures: Performing tasks like indexing, slicing, and transforming data using lists and dictionaries
# - **Source:** `DETAILED_UNIT_DESCRIPTIONS.md` - Unit 1 Practical Content
#
# ---
#
# ## Introduction
#
# **Lists and dictionaries** are fundamental Python data structures for storing and manipulating data, essential for data science workflows.

# %%
print("✅ Libraries imported!")
print("\nWorking with Data Structures")
print("=" * 60)

print("\nLists:")
print("  - Indexing: Access elements by position")
print("  - Slicing: Extract sublists")
print("  - Methods: append, extend, insert, remove")
print("  - List comprehensions")

print("\nDictionaries:")
print("  - Key-value pairs")
print("  - Access by key")
print("  - Methods: get, keys, values, items")
print("  - Dictionary comprehensions")

print("\nTransformations:")
print("  - List to dictionary")
print("  - Dictionary to list")
print("  - Nested structures")
print("  - Data filtering")

print("\n✅ Data structures concepts understood!")
# Out:
# ✅ Libraries imported!
#
# Working with Data Structures
# ...
#
# Lists:
#   - Indexing: Access elements by position
#   - Slicing: Extract sublists
#   - Methods: append, extend, insert, remove
#   - List comprehensions
#
# Dictionaries:
#   - Key-value pairs
#   - Access by key
#   - Methods: get, keys, values, items
#   - Dictionary comprehensions
#
# Transformations:
#   - List to dictionary
#   - Dictionary to list
#   - Nested structures
#   - Data filtering
#
# ✅ Data structures concepts understood!
