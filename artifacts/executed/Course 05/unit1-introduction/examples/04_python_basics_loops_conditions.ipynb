# %% [markdown]
# # Python Programming: Basic Tasks (Arithmetic, Loops, Conditions)
#
# ## 📚 Learning Objectives
#
# By completing this notebook, you will:
# - Execute Python code for arithmetic operations
# - Use loops (for, while)
# - Use conditional statements (if, elif, else)
# - Solve basic programming tasks
# - Apply Python fundamentals
#
# ## 🔗 Prerequisites
#
# - ✅ Basic Python knowledge
# - ✅ Understanding of programming concepts
#
# ---
#
# ## Official Structure Reference
#
# This notebook covers practical activities from **Course 05, Unit 1**:
# - Python Programming: Executing Python code to solve basic tasks like arithmetic operations, loops, and conditions
# - **Source:** `DETAILED_UNIT_DESCRIPTIONS.md` - Unit 1 Practical Content
#
# ---
#
# ## Introduction
#
# **Python programming fundamentals** are essential for data science, covering arithmetic operations, control flow with loops and conditions, and basic problem-solving.

# %%
print("✅ Libraries imported!")
print("\nPython Programming: Basic Tasks")
print("=" * 60)

print("\nArithmetic Operations:")
print("  - Addition (+), Subtraction (-)")
print("  - Multiplication (*), Division (/)")
print("  - Modulo (%), Exponentiation (**)")
print("  - Floor division (//)")

print("\nLoops:")
print("  - for loop: Iterate over sequences")
print("  - while loop: Repeat while condition true")
print("  - List comprehensions")
print("  - Nested loops")

print("\nConditional Statements:")
print("  - if: Single condition")
print("  - elif: Multiple conditions")
print("  - else: Default case")
print("  - Nested conditions")

print("\n✅ Python basics concepts understood!")
# Out:
# ✅ Libraries imported!
#
# Python Programming: Basic Tasks
# ...
#
# Arithmetic Operations:
#   - Addition (+), Subtraction (-)
#   - Multiplication (*), Division (/)
#   - Modulo (%), Exponentiation (**)
#   - Floor division (//)
#
# Loops:
#   - for loop: Iterate over sequences
#   - while loop: Repeat while condition true
#   - List comprehensions
#   - Nested loops
#
# Conditional Statements:
#   - if: Single condition
#   - elif: Multiple conditions
#   - else: Default case
#   - Nested conditions
#
# ✅ Python basics concepts understood!
