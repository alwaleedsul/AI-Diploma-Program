# %% [markdown]
# # Using Jupyter Notebooks: Writing and Executing Code
#
# ## 📚 Learning Objectives
#
# By completing this notebook, you will:
# - Write code in Jupyter Notebooks
# - Execute code cells
# - Combine explanation and code
# - Ensure reproducibility
# - Follow best practices
#
# ## 🔗 Prerequisites
#
# - ✅ Basic Jupyter Notebook knowledge
# - ✅ Understanding of code documentation
#
# ---
#
# ## Official Structure Reference
#
# This notebook covers practical activities from **Course 05, Unit 1**:
# - Using Jupyter Notebooks: Writing and executing code in Jupyter Notebooks, combining explanation and code to ensure reproducibility
# - **Source:** `DETAILED_UNIT_DESCRIPTIONS.md` - Unit 1 Practical Content
#
# ---
#
# ## Introduction
#
# **Jupyter Notebooks** provide an interactive environment for combining code, documentation, and visualizations, essential for reproducible data science work.

# %%
print("✅ Libraries imported!")
print("\nJupyter Notebooks Best Practices")
print("=" * 60)

print("\nNotebook Structure:")
print("  - Markdown cells for documentation")
print("  - Code cells for execution")
print("  - Clear section headers")
print("  - Logical flow")

print("\nBest Practices:")
print("  - Clear variable names")
print("  - Comments and explanations")
print("  - Reproducible code")
print("  - Version control")
print("  - Clear outputs")

print("\nReproducibility:")
print("  - Set random seeds")
print("  - Document dependencies")
print("  - Include data sources")
print("  - Clear execution order")

print("\n✅ Jupyter Notebook best practices understood!")
# Out:
# ✅ Libraries imported!
#
# Jupyter Notebooks Best Practices
# ...
#
# Notebook Structure:
#   - Markdown cells for documentation
#   - Code cells for execution
#   - Clear section headers
#   - Logical flow
#
# Best Practices:
#   - Clear variable names
#   - Comments and explanations
#   - Reproducible code
#   - Version control
#   - Clear outputs
#
# Reproducibility:
#   - Set random seeds
#   - Document dependencies
#   - Include data sources
#   - Clear execution order
#
# ✅ Jupyter Notebook best practices understood!
