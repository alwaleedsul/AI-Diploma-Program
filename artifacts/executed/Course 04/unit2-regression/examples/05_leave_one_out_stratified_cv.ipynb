# %% [markdown]
# # Performing Leave-One-Out and Stratified Cross-Validation
#
# ## 📚 Learning Objectives
#
# By completing this notebook, you will:
# - Implement leave-one-out cross-validation
# - Implement stratified cross-validation
# - Compare CV methods
# - Apply to regression models
# - Understand CV trade-offs
#
# ## 🔗 Prerequisites
#
# - ✅ Understanding of cross-validation
# - ✅ Understanding of data splitting
# - ✅ Scikit-learn knowledge
#
# ---
#
# ## Official Structure Reference
#
# This notebook covers practical activities from **Course 04, Unit 2**:
# - Performing leave-one-out and stratified cross-validation
# - **Source:** `DETAILED_UNIT_DESCRIPTIONS.md` - Unit 2 Practical Content
#
# ---
#
# ## Introduction
#
# **Leave-one-out** and **stratified cross-validation** are advanced CV techniques that provide robust model evaluation, especially useful for small datasets or imbalanced data.

# %%
import numpy as np
from sklearn.model_selection import LeaveOneOut, StratifiedKFold, cross_val_score
from sklearn.linear_model import LinearRegression

print("✅ Libraries imported!")
print("\nLeave-One-Out and Stratified Cross-Validation")
print("=" * 60)

print("\nLeave-One-Out CV:")
print("  - Each sample as test set")
print("  - Maximum data usage")
print("  - Computationally expensive")

print("\nStratified Cross-Validation:")
print("  - Preserves class distribution")
print("  - Important for imbalanced data")
print("  - Better for classification")

print("\n✅ Advanced CV concepts understood!")
# Out:
# ✅ Libraries imported!
#
# Leave-One-Out and Stratified Cross-Validation
# ...
#
# Leave-One-Out CV:
#   - Each sample as test set
#   - Maximum data usage
#   - Computationally expensive
#
# Stratified Cross-Validation:
#   - Preserves class distribution
#   - Important for imbalanced data
#   - Better for classification
#
# ✅ Advanced CV concepts understood!
