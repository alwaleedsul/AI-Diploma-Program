# %% [markdown]
# # Real-World AI Applications
#
# ## 📚 Learning Objectives
#
# By completing this notebook, you will:
# - Explore real-world AI applications
# - Understand AI in different industries
# - Analyze case studies
# - Understand practical impacts
#
# ## 🔗 Prerequisites
#
# - ✅ Understanding of AI fundamentals
# - ✅ Python programming knowledge
#
# ---
#
# ## Official Structure Reference
#
# This notebook covers practical activities from **Course 02, Unit 1**:
# - Real-world AI applications
# - **Source:** `DETAILED_UNIT_DESCRIPTIONS.md` - Unit 1 Practical Content
#
# ---
#
# ## Introduction
#
# **Real-world AI applications** demonstrate how AI is transforming industries including healthcare, finance, autonomous systems, and more.

# %% [markdown]
# ## 📥 Inputs & 📤 Outputs | المدخلات والمخرجات
#
# **Inputs:** What we use in this notebook
#
# - Libraries and concepts as introduced in this notebook; see prerequisites and code comments.
#
# **Outputs:** What you'll see when you run the cells
#
# - Printed results, figures, and summaries as shown when you run the cells.
#
# ---

# %%
print("✅ Libraries imported!")
print("\nReal-World AI Applications")
print("=" * 60)

# AI Applications by Industry
ai_applications = {
    'Healthcare': [
        'Medical diagnosis', 'Drug discovery',
        'Personalized treatment',
        'Medical imaging analysis'
    ],
    'Finance': [
        'Fraud detection',
        'Algorithmic trading',
        'Credit scoring',
        'Risk assessment'
    ],
    'Autonomous Systems': [
        'Self-driving cars',
        'Drones',
        'Robotics',
        'Navigation systems'
    ],
    'Natural Language Processing': [
        'Chatbots',
        'Translation',
        'Sentiment analysis',
        'Text generation'
    ]
}

print("\nAI Applications by Industry:")
for industry, applications in ai_applications.items():
    print(f"\n{industry}:")
    for app in applications:
        print(f"  - {app}")

print("\n✅ AI applications overview completed!")
