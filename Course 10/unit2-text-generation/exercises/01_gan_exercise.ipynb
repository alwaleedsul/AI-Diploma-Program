# %% [markdown]
# # Exercise: Generate Realistic Faces
# ## AIAT 124 - Generative AI
#
# ## Learning Objectives
#
# - Implement GAN architecture
# - Train GAN to generate faces
# - Evaluate generation quality
# - Apply to creative design
#
# ## Real-World Context
#
# Generate realistic faces for character design, avatars, creative content.
#
# **Task**: Build GAN to generate realistic faces.
#
# ---
#
# ## Task 1: GAN Architecture (35 points)
#
# Implement GAN:
# 1. Generator network
# 2. Discriminator network
# 3. Loss functions

# %% [markdown]
# ## 📥 Inputs & 📤 Outputs | المدخلات والمخرجات
#
# **Inputs:** What we use in this notebook
#
# - Libraries and concepts as introduced in this notebook; see prerequisites and code comments.
#
# **Outputs:** What you'll see when you run the cells
#
# - Printed results, figures, and summaries as shown when you run the cells.
#
# ---

# %%
# %pip install torch torchvision -q
import torch.nn as nn

# TODO: Implement Generator
class Generator(nn.Module):
    # YOUR CODE HERE
    pass

# TODO: Implement Discriminator
class Discriminator(nn.Module):
    # YOUR CODE HERE
    pass

# %% [markdown]
# ## Task 2: Training (30 points)
#
# Train GAN:
# 1. Train discriminator
# 2. Train generator
# 3. Balance training

# %% [markdown]
# TODO: Implement training loop
# YOUR CODE HERE

# %% [markdown]
# ## Task 3: Generation and Evaluation (35 points)
#
# Generate faces and evaluate quality.
#
# **Submission**: Complete notebook with trained GAN.
#
# **Grading**: 100 points total
