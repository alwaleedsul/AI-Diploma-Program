# %% [markdown]
# # Unit 2 - Exercise 1: Data Cleaning Practice
# ## تمرين 1: ممارسة تنظيف البيانات
#
# **Instructions:** Complete the tasks in `exercise_01.py` in this folder.
#
# You can run the script below, or work through the same tasks in cells. Use **Kernel → Restart & Run All** to execute.

# %% [markdown]
# ## Official Structure Reference
#
# This notebook supports **Course 05, Unit 2** requirements from `DETAILED_UNIT_DESCRIPTIONS.md`.
#
# ---

# %% [markdown]
# ## The Story | القصة
#
# **BEFORE**: You know basic data cleaning but don't understand Unit 2 - Exercise 1: Data Cleaning Practice deeply.
#
# **AFTER**: You'll master Unit 2 - Exercise 1: Data Cleaning Practice and understand how it fits into the data preparation workflow!
#
# **Why this matters**: Unit 2 - Exercise 1: Data Cleaning Practice is essential for building complete, professional data science solutions!
#
# ---

# %%
# %run exercise_01.py
# Out:
# ...
# Task 1: Identify Missing Values
# ...
#
# ...
# Task 2: Handle Missing Values
# ...
#
# ...
# Task 3: Handle Duplicates
# ...
#
# ...
# Task 4: Identify Outliers
# ...
#
# ...
# Task 5: Handle Outliers
# ...
#
# ...
# Task 6: Data Transformation
# ...
#
# ...
# Exercise 1 Complete!
# ...
