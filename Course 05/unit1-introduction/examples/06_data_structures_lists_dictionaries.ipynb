# %% [markdown]
# # 06. Working with Data Structures | العمل مع هياكل البيانات
# ## Lists and Dictionaries | القوائم والقواميس
#
# ## 📚 Learning Objectives
#
# By completing this notebook, you will:
# - Work with lists: indexing, slicing, and transformations
# - Work with dictionaries: key-value pairs and operations
# - Transform data between structures
# - Apply data manipulation techniques
# - Use common operations for data science
#
# ## 🔗 Prerequisites
#
# - ✅ Example 4: Python Basics (loops and conditions)
# - ✅ Example 5: Jupyter Notebooks Best Practices
# - ✅ Understanding of variables and data types
#
# ---
#
# ## Official Structure Reference
#
# This notebook covers practical activities from **Course 05, Unit 1**:
# - Working with Data Structures: Performing tasks like indexing, slicing, and transforming data using lists and dictionaries
# - **Source:** `DETAILED_UNIT_DESCRIPTIONS.md` - Unit 1 Practical Content
#
# ---
#
# ## 📚 Prerequisites (What You Need First) | المتطلبات الأساسية
#
# **BEFORE starting this notebook**, you should have completed:
# - ✅ **Example 4: Python Basics** - You need loops and conditions!
# - ✅ **Example 5: Jupyter Best Practices** - You need to know how to write notebooks!
# - ✅ **Understanding of variables**: What are variables? How to assign values?
#
# **If you haven't completed these**, you might struggle with:
# - Understanding how to access list elements
# - Knowing when to use lists vs dictionaries
# - Understanding data structure operations
# - Transforming data between formats
#
# ---
#
# ## 🔗 Where This Notebook Fits | مكان هذا الدفتر
#
# **This is the SIXTH example** - it teaches you how to organize data!
#
# **Why this example SIXTH?**
# - **Before** you can organize data, you need Python basics (Example 4)
# - **Before** you can work with pandas DataFrames, you need to understand lists/dictionaries
# - **After** learning this, you'll understand how pandas stores data internally
#
# **Builds on**:
# - 📓 Example 4: Python Basics (loops and conditions needed)
# - 📓 Example 5: Jupyter Best Practices (how to write notebooks)
#
# **Leads to**:
# - 📓 Example 2: Pandas & NumPy Basics (pandas uses lists/dictionaries internally!)
# - 📓 Unit 2: Data Cleaning (heavily uses data structures)
#
# **Why this order?**
# 1. Data structures teach you **how to organize data** (needed for all data science)
# 2. Lists and dictionaries are **foundation structures** (used everywhere)
# 3. These skills are **prerequisites** for pandas and data manipulation
#
# ---
#
# ## The Story: Organizing Your Tools | القصة: تنظيم أدواتك
#
# Imagine you're organizing a toolbox. **Before** you can work efficiently, you need to know how to organize tools - some go in drawers (lists), some have labels (dictionaries). **After** organizing properly, you can find any tool instantly!
#
# Same with data: **Before** analyzing data, we learn data structures - lists for sequences, dictionaries for labeled data. **After** mastering structures, we can organize any data efficiently!
#
# ---
#
# ## Why Data Structures Matter | لماذا يهم هياكل البيانات
#
# Data structures are essential because:
# - **Lists**: Store sequences of data (like rows in a table)
# - **Dictionaries**: Store labeled data (like columns with names)
# - **Together**: They form the foundation for pandas DataFrames
# - **In data science**: All data manipulation uses these structures
#
# **Common Student Questions:**
# - **Q: When do I use a list vs dictionary?**
#   - Answer: Lists for ordered sequences, dictionaries for labeled data
#   - Example: List = [1, 2, 3] (just values), Dict = {'name': 'John', 'age': 25} (labeled)
#   - In data science: Lists for rows, dictionaries for records with fields
#
# - **Q: What is indexing and slicing?**
#   - Answer: Indexing = get one item, Slicing = get multiple items
#   - Example: `list[0]` = first item, `list[0:3]` = first three items
#   - In data science: Extract specific rows or columns from data
#
# ---
#
# ## Introduction
#
# **Lists and dictionaries** are fundamental Python data structures for storing and manipulating data. Mastering these structures is essential for data science workflows, as pandas DataFrames are built on these concepts.

# %%
# ============================================================================# PART 1: LISTS | القوائم# ============================================================================print("=" * 70)print("Working with Data Structures | العمل مع هياكل البيانات")print("=" * 70)print("\n📋 PART 1: Lists | القوائم")print("-" * 70)# Example 1: Creating and accessing listsprint("\n✅ Example 1: Creating and Accessing Lists")print("-" * 70)# Create a listfruits = ["apple", "banana", "orange", "grape", "mango"]print(f"   List: {fruits}")# Indexing: Access single elementprint(f"   First fruit (index 0): {fruits[0]}")print(f"   Last fruit (index -1): {fruits[-1]}")# Slicing: Access multiple elementsprint(f"   First 3 fruits (slice [0:3]): {fruits[0:3]}")print(f"   Last 2 fruits (slice [-2:]): {fruits[-2:]}")# Example 2: List methodsprint("\n✅ Example 2: List Methods")print("-" * 70)

# %% [markdown]
# ## Step 2
#
# **What we're doing:** This section covers step 2.
#
# **Why it matters:** Understanding this helps you master the concepts.

# %%
numbers = [1, 2, 3]print(f"   Original: {numbers}")# Add elementsnumbers.append(4)  # Add to endprint(f"   After append(4): {numbers}")numbers.insert(1, 10)  # Insert at position 1print(f"   After insert(1, 10): {numbers}")# Remove elementsnumbers.remove(10)  # Remove value 10print(f"   After remove(10): {numbers}")# List comprehensions (powerful feature!)squared = [x ** 2 for x in range(1, 6)]print(f"   Squared numbers [1-5]: {squared}")# Real-world example: Process dataprint("\n📊 Real-world example: Process student scores")scores = [85, 90, 78, 92, 88]print(f"   Scores: {scores}")print(f"   Highest: {max(scores)}")print(f"   Lowest: {min(scores)}")print(f"   Average: {sum(scores) / len(scores):.2f}")# ============================================================================# PART 2: DICTIONARIES | القواميس# ============================================================================print("\n" + "=" * 70)

# %% [markdown]
# ## Step 3
#
# **What we're doing:** This section covers step 3.
#
# **Why it matters:** Understanding this helps you master the concepts.

# %%
print("PART 2: Dictionaries | القواميس")print("=" * 70)# Example 1: Creating and accessing dictionariesprint("\n✅ Example 1: Creating and Accessing Dictionaries")print("-" * 70)# Create a dictionary (key-value pairs)student = {    "name": "Ahmed",    "age": 20,    "grade": "A",    "courses": ["Math", "Python", "Data Science"]}print(f"   Student dictionary: {student}")# Access by keyprint(f"   Name: {student['name']}")print(f"   Age: {student['age']}")# Safe access with .get() (returns None if key doesn't exist)print(f"   Email: {student.get('email', 'Not provided')}")# Example 2: Dictionary methodsprint("\n✅ Example 2: Dictionary Methods")print("-" * 70)print(f"   Keys: {list(student.keys())}")print(f"   Values: {list(student.values())}")print(f"   Items: {list(student.items())}")

# %% [markdown]
# ## Step 4
#
# **What we're doing:** This section covers step 4.
#
# **Why it matters:** Understanding this helps you master the concepts.

# %%
# Add/update valuesstudent["email"] = "ahmed@example.com"print(f"   After adding email: {student['email']}")# Real-world example: Store multiple recordsprint("\n📊 Real-world example: Store multiple student records")students = [    {"name": "Ahmed", "score": 85},    {"name": "Sara", "score": 92},    {"name": "Mohammed", "score": 78}]print("   Student records:")for student_record in students:    print(f"   - {student_record['name']}: {student_record['score']}")# ============================================================================# PART 3: TRANSFORMATIONS | التحويلات# ============================================================================print("\n" + "=" * 70)print("PART 3: Transformations | التحويلات")print("=" * 70)# Example 1: List to Dictionaryprint("\n✅ Example 1: List to Dictionary")print("-" * 70)# Convert list of tuples to dictionarypairs = [("name", "Ahmed"), ("age", 20), ("city", "Riyadh")]student_dict = dict(pairs)print(f"   Pairs: {pairs}")

# %% [markdown]
# ## Step 5
#
# **What we're doing:** This section covers step 5.
#
# **Why it matters:** Understanding this helps you master the concepts.

# %%
print(f"   Dictionary: {student_dict}")# Example 2: Dictionary to Listprint("\n✅ Example 2: Dictionary to List")print("-" * 70)data = {"a": 1, "b": 2, "c": 3}keys_list = list(data.keys())values_list = list(data.values())print(f"   Dictionary: {data}")print(f"   Keys as list: {keys_list}")print(f"   Values as list: {values_list}")# Example 3: Nested structuresprint("\n✅ Example 3: Nested Structures")print("-" * 70)# List of dictionaries (common in data science!)employees = [    {"name": "Ahmed", "department": "IT", "salary": 5000},    {"name": "Sara", "department": "HR", "salary": 4500},    {"name": "Mohammed", "department": "IT", "salary": 5500}]print("   Employees:")for emp in employees:    print(f"   - {emp['name']}: {emp['department']}, ${emp['salary']}")# Filter datait_employees = [emp for emp in employees if emp['department'] == 'IT']print(f"\n   IT Department employees: {len(it_employees)}")

# %% [markdown]
# ## Step 6
#
# **What we're doing:** This section covers step 6.
#
# **Why it matters:** Understanding this helps you master the concepts.

# %%
for emp in it_employees:    print(f"   - {emp['name']}")# ============================================================================# PART 4: DATA SCIENCE APPLICATIONS | تطبيقات علم البيانات# ============================================================================print("\n" + "=" * 70)print("PART 4: Data Science Applications | تطبيقات علم البيانات")print("=" * 70)# Example: Prepare data for pandasprint("\n📊 Example: Prepare Data for Pandas DataFrame")print("-" * 70)# Data as list of dictionaries (common format!)sales_data = [    {"date": "2024-01-01", "product": "A", "sales": 100},    {"date": "2024-01-02", "product": "B", "sales": 150},    {"date": "2024-01-03", "product": "A", "sales": 120},    {"date": "2024-01-04", "product": "C", "sales": 200}]print("   Sales data (list of dictionaries):")for record in sales_data:    print(f"   {record}")# Extract specific informationdates = [record["date"] for record in sales_data]sales = [record["sales"] for record in sales_data]print(f"\n   Dates: {dates}")

# %% [markdown]
# ## Step 7
#
# **What we're doing:** This section covers step 7.
#
# **Why it matters:** Understanding this helps you master the concepts.

# %%
print(f"   Sales: {sales}")print(f"   Total sales: ${sum(sales)}")# ============================================================================# SUMMARY | الملخص# ============================================================================print("\n" + "=" * 70)print("Summary | الملخص")print("=" * 70)print("""✅ What you learned:   1. Lists: Ordered sequences, indexing, slicing, methods   2. Dictionaries: Key-value pairs, access by key, methods   3. Transformations: Convert between structures   4. Applications: Prepare data for pandas, filter, process🎯 Key Takeaways:   - Lists: Use for ordered sequences (rows, arrays)   - Dictionaries: Use for labeled data (records, columns)   - Transformations: Convert formats as needed   - Together: Foundation for pandas DataFrames📚 Next Steps:   - Example 2: Pandas & NumPy Basics (uses these structures!)   - Example 7: Data Science Applications (apply these skills)   - Unit 2: Data Cleaning (heavily uses lists and dictionaries)""")print("✅ Data structures concepts understood!")
