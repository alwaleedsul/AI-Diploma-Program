# %% [markdown]
# # 08. Hyperparameter Tuning Using Grid Search and Random Search
#
# ## 📚 Learning Objectives
#
# By completing this notebook, you will:
# - Perform hyperparameter tuning
# - Use Grid Search
# - Use Random Search
# - Optimize model parameters
# - Compare search strategies
#
# ## 🔗 Prerequisites
#
# - ✅ Understanding of hyperparameters
# - ✅ Understanding of model tuning
# - ✅ Scikit-learn knowledge
#
# ---
#
# ## Official Structure Reference
#
# This notebook covers practical activities from **Course 05, Unit 4**:
# - Hyperparameter tuning using techniques like Grid Search and Random Search
# - **Source:** `DETAILED_UNIT_DESCRIPTIONS.md` - Unit 4 Practical Content
#
# ---
#
# ## Introduction
#
# **Hyperparameter tuning** optimizes model performance by systematically searching for the best parameter values using Grid Search or Random Search techniques.

# %% [markdown]
# ## The Story | القصة
#
# **BEFORE**: You can train models but don't know how to optimize their performance.
#
# **AFTER**: You'll learn hyperparameter tuning: grid search, random search, and finding the best model parameters!
#
# **Why this matters**: Hyperparameter Tuning Using Grid Search and Random Search is essential for building complete, professional data science solutions!
#
# ---

# %% [markdown]
# ## 📥 Inputs & 📤 Outputs | المدخلات والمخرجات
#
# **Inputs:** What we use in this notebook
#
# - Model, param grid
# - sklearn
#
# **Outputs:** What you'll see when you run the cells
#
# - Best params
# - CV results
# - Printed summary
#
# ---

# %%
import numpy as np
from sklearn.model_selection import GridSearchCV, RandomizedSearchCV
from sklearn.ensemble import RandomForestClassifier
from scipy.stats import randint
print("✅ Libraries imported!")
print("\nHyperparameter Tuning: Grid Search and Random Search")
print("=" * 60)

print("\nGrid Search:")
print("  - Exhaustive search")
print("  - Tests all combinations")
print("  - Guarantees best in grid")
print("  - Computationally expensive")

print("\nRandom Search:")
print("  - Random sampling")
print("  - More efficient")
print("  - Good for large spaces")
print("  - Often finds good solutions")

print("\nHyperparameters:")
print("  - Learning rate")
print("  - Number of trees")
print("  - Max depth")
print("  - Regularization strength")

print("\n✅ Hyperparameter tuning concepts understood!")
# Out:
# ✅ Libraries imported!
#
# Hyperparameter Tuning: Grid Search and Random Search
# ============================================================
#
# Grid Search:
#   - Exhaustive search
#   - Tests all combinations
#   - Guarantees best in grid
#   - Computationally expensive
#
# Random Search:
#   - Random sampling
#   - More efficient
#   - Good for large spaces
#   - Often finds good solutions
#
# Hyperparameters:
#   - Learning rate
#   - Number of trees
#   - Max depth
#   - Regularization strength
#
# ✅ Hyperparameter tuning concepts understood!

# %% [markdown]
# ## Part 1
#
# ## 📚 Learning Objectives
#
# By completing this notebook, you will:
# - Perform hyperparameter tuning
# - Use Grid Search
# - Use Random Search
# - Optimize model parameters
# - Improve model performance
#
# ## 🔗 Prerequisites
#
# - ✅ Understanding of hyperparameters
# - ✅ Understanding of model tuning
# - ✅ Scikit-learn knowledge
#
# ---
#
# ## Official Structure Reference
#
# This notebook covers practical activities from **Course 05, Unit 4**:
# - Hyperparameter tuning using techniques like Grid Search and Random Search
# - **Source:** `DETAILED_UNIT_DESCRIPTIONS.md` - Unit 4 Practical Content
#
# ---
#
# ## Introduction
#
# **Hyperparameter tuning** optimizes model parameters to improve performance, using systematic search strategies like Grid Search and Random Search.

# %%
import numpy as np
from sklearn.model_selection import GridSearchCV, RandomizedSearchCV
from sklearn.ensemble import RandomForestClassifier
from scipy.stats import randint
print("✅ Libraries imported!")
print("\nHyperparameter Tuning: Grid Search and Random Search")
print("=" * 60)

print("\nGrid Search:")
print("  - Exhaustive search")
print("  - Tests all combinations")
print("  - Guarantees best in grid")
print("  - Computationally expensive")

print("\nRandom Search:")
print("  - Random sampling")
print("  - More efficient")
print("  - Good for large spaces")
print("  - Often finds good solutions")

print("\nHyperparameters:")
print("  - Learning rate")
print("  - Tree depth")
print("  - Number of estimators")
print("  - Regularization strength")

print("\n✅ Hyperparameter tuning concepts understood!")
# Out:
# ✅ Libraries imported!
#
# Hyperparameter Tuning: Grid Search and Random Search
# ============================================================
#
# Grid Search:
#   - Exhaustive search
#   - Tests all combinations
#   - Guarantees best in grid
#   - Computationally expensive
#
# Random Search:
#   - Random sampling
#   - More efficient
#   - Good for large spaces
#   - Often finds good solutions
#
# Hyperparameters:
#   - Learning rate
#   - Tree depth
#   - Number of estimators
#   - Regularization strength
#
# ✅ Hyperparameter tuning concepts understood!

# %% [markdown]
# ## Part 2
#
# ## 📚 Learning Objectives
#
# By completing this notebook, you will:
# - Perform hyperparameter tuning
# - Use Grid Search
# - Use Random Search
# - Optimize model parameters
# - Improve model performance
#
# ## 🔗 Prerequisites
#
# - ✅ Understanding of hyperparameters
# - ✅ Understanding of model tuning
# - ✅ Scikit-learn knowledge
#
# ---
#
# ## Official Structure Reference
#
# This notebook covers practical activities from **Course 05, Unit 4**:
# - Hyperparameter tuning using techniques like Grid Search and Random Search
# - **Source:** `DETAILED_UNIT_DESCRIPTIONS.md` - Unit 4 Practical Content
#
# ---
#
# ## Introduction
#
# **Hyperparameter tuning** optimizes model parameters to improve performance, using systematic search strategies like Grid Search and Random Search.

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import GridSearchCV, RandomizedSearchCV
from sklearn.ensemble import RandomForestClassifier
from scipy.stats import randint
print("✅ Libraries imported!")
print("\nHyperparameter Tuning: Grid Search and Random Search")
print("=" * 60)

print("\nHyperparameters:")
print("  - Model configuration parameters")
print("  - Not learned from data")
print("  - Set before training")
print("  - Examples: learning rate, tree depth")

print("\nGrid Search:")
print("  - Exhaustive search")
print("  - Tests all combinations")
print("  - Guarantees best in grid")
print("  - Computationally expensive")

print("\nRandom Search:")
print("  - Random sampling")
print("  - More efficient")
print("  - Often finds good solutions")
print("  - Better for large spaces")

print("\n✅ Hyperparameter tuning concepts understood!")
# Out:
# ✅ Libraries imported!
#
# Hyperparameter Tuning: Grid Search and Random Search
# ============================================================
#
# Hyperparameters:
#   - Model configuration parameters
#   - Not learned from data
#   - Set before training
#   - Examples: learning rate, tree depth
#
# Grid Search:
#   - Exhaustive search
#   - Tests all combinations
#   - Guarantees best in grid
#   - Computationally expensive
#
# Random Search:
#   - Random sampling
#   - More efficient
#   - Often finds good solutions
#   - Better for large spaces
#
# ✅ Hyperparameter tuning concepts understood!
