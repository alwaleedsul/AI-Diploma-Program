# %% [markdown]
# # Visualizing Results Using Graphs, Confusion Matrices, or Heat Maps
#
# ## 📚 Learning Objectives
#
# By completing this notebook, you will:
# - Visualize model results
# - Create confusion matrices
# - Generate heat maps
# - Plot performance graphs
# - Present results effectively
#
# ## 🔗 Prerequisites
#
# - ✅ Understanding of visualization
# - ✅ Matplotlib/Seaborn knowledge
# - ✅ Result interpretation skills
#
# ---
#
# ## Official Structure Reference
#
# This notebook covers practical activities from **Course 12, Unit 4**:
# - Visualizing results using graphs, confusion matrices, or heat maps
# - **Source:** `DETAILED_UNIT_DESCRIPTIONS.md` - Unit 4 Practical Content
#
# ---
#
# ## Introduction
#
# **Visualizing results** helps communicate model performance effectively through graphs, confusion matrices, and heat maps that highlight key findings.

# %% [markdown]
# ## 📥 Inputs & 📤 Outputs | المدخلات والمخرجات
#
# **Inputs:** What we use in this notebook
#
# - Libraries and concepts as introduced in this notebook; see prerequisites and code comments.
#
# **Outputs:** What you'll see when you run the cells
#
# - Printed results, figures, and summaries as shown when you run the cells.
#
# ---

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from sklearn.metrics import confusion_matrix

print("✅ Libraries imported!")
print("\nVisualizing Results")
print("=" * 60)

print("\nVisualization Types:")
print("  - Performance graphs")
print("  - Confusion matrices")
print("  - Heat maps")
print("  - ROC curves")
print("  - Learning curves")

print("\nConfusion Matrices:")
print("  - Classification results")
print("  - True/False positives/negatives")
print("  - Error patterns")
print("  - Class-wise performance")

print("\nHeat Maps:")
print("  - Correlation matrices")
print("  - Feature importance")
print("  - Attention weights")
print("  - Performance comparisons")

print("\n✅ Visualization concepts understood!")
