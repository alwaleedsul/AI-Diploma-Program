# %% [markdown]
# # 01 Transformer Attention
#
# ## 📚 Learning Objectives
#
# By completing this notebook, you will:
# - Implement self-attention and transformer blocks
# - Understand scaling and positional encodings
#
# ## 🔗 Prerequisites
#
# - ✅ Basic Python
# - ✅ Basic NumPy/Pandas (when applicable)
#
# ---
#
# ## Official Structure Reference
#
# This notebook supports **Course 08, Unit 4** requirements from `DETAILED_UNIT_DESCRIPTIONS.md`.
#
# ---
