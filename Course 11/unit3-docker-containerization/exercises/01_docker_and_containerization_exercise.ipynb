# %% [markdown]
# # Exercise 01: Docker and Containerization
# ## AIAT 125 - AI Model Deployment
#
# ---
#
# ## Learning Objectives
#
# In this exercise, you will:
# - Dockerize ML models
# - Deploy on Kubernetes
# - Configure auto-scaling
# - Manage containerized deployments
#
# ---
#
# ## Real-World Context
#
# You are containerizing an ML model for scalable deployment using Docker and Kubernetes.
#
# ---

# %%
# Setup
# TODO: Install required libraries
# %pip install ...

# TODO: Import libraries
# YOUR CODE HERE

print('✅ Setup complete!')

# %% [markdown]
# ## Task 1: Dockerize Model (40 points)
#
# Create Dockerfile and containerize your ML model.
#
# **Requirements:**
# - Write Dockerfile
# - Build Docker image
# - Test container
# - Optimize image size

# %%
# TODO: Implement solution
# YOUR CODE HERE

# %% [markdown]
# ## Task 2: Kubernetes Deployment (40 points)
#
# Deploy containerized model on Kubernetes.
#
# **Requirements:**
# - Create deployment manifest
# - Set up service
# - Configure ingress
# - Test deployment

# %%
# TODO: Implement solution
# YOUR CODE HERE

# %% [markdown]
# ## Task 3: Scaling Configuration (20 points)
#
# Configure auto-scaling for your deployment.
#
# **Requirements:**
# - Set up HPA (Horizontal Pod Autoscaler)
# - Configure resource limits
# - Test scaling
# - Monitor performance

# %%
# TODO: Implement solution
# YOUR CODE HERE

# %% [markdown]
# ---
#
# ## Submission
#
# **Submission**: Complete notebook with all tasks implemented
#
# **Grading**: 100 points total
