# %% [markdown]
# # Exercise: Model Monitoring Dashboard
# ## AIAT 125 - Model Deployment
#
# ## Learning Objectives
#
# - Set up model monitoring
# - Track performance metrics
# - Detect model drift
# - Create monitoring dashboard
#
# ## Real-World Context
#
# Monitor deployed model performance and detect issues.
#
# **Task**: Build monitoring system for production model.
#
# ---
#
# ## Task 1: Performance Monitoring (35 points)
#
# Implement monitoring:
# 1. Track predictions
# 2. Calculate metrics
# 3. Log performance

# %% [markdown]
# ## 📥 Inputs & 📤 Outputs | المدخلات والمخرجات
#
# **Inputs:** What we use in this notebook
#
# - Libraries and concepts as introduced in this notebook; see prerequisites and code comments.
#
# **Outputs:** What you'll see when you run the cells
#
# - Printed results, figures, and summaries as shown when you run the cells.
#
# ---

# %%
# %pip install pandas matplotlib -q
import pandas as pd
import matplotlib.pyplot as plt

# TODO: Implement monitoring
class ModelMonitor:
    # YOUR CODE HERE
    pass

# %% [markdown]
# ## Task 2: Drift Detection (30 points)
#
# Detect model drift:
# 1. Data drift detection
# 2. Concept drift detection
# 3. Alert system

# %% [markdown]
# TODO: Implement drift detection
# YOUR CODE HERE

# %% [markdown]
# ## Task 3: Dashboard Creation (35 points)
#
# Create monitoring dashboard.
#
# **Submission**: Complete notebook with monitoring system.
#
# **Grading**: 100 points total
