# %% [markdown]
# # Local Deployment and Testing
#
# ## 📚 Learning Objectives
#
# By completing this notebook, you will:
# - Understand the key concepts of this topic
# - Apply the topic using Python code examples
# - Practice with small, realistic datasets or scenarios
#
# ## 🔗 Prerequisites
#
# - ✅ Basic Python
# - ✅ Basic NumPy/Pandas (when applicable)
#
# ---
#
# ## Official Structure Reference
#
# This notebook supports **Course 11, Unit 1** requirements from `DETAILED_UNIT_DESCRIPTIONS.md`.
#
# ---

# %% [markdown]
# # Local Deployment and Testing
# ## AIAT 125 - AI Model Deployment
#
# ---
#
# ## 📚 Learning Objectives | أهداف التعلم
#
# This notebook demonstrates key concepts through hands-on examples.
#
# By completing this notebook, you will:
# - Deploy models locally
# - Test deployed models
# - Monitor local deployments
# - Handle errors and edge cases
#
# ---
#
# ## 🔗 Prerequisites | المتطلبات الأساسية
#
# - ✅ Python 3.8+ installed
# - ✅ Required libraries (see `requirements.txt`)
# - ✅ Basic Python knowledge
#
# ---
#
# ## Real-World Context
#
# You are deploying a sentiment analysis model locally and need to test it thoroughly before moving to production.
#
# ---

# %% [markdown]
# ## Local Model Deployment
#
# Deploy model as local service.

# %%
from flask import Flask, request, jsonify
import joblib

# Load model
# model = joblib.load('model.pkl')

app = Flask(__name__)

@app.route('/predict', methods=['POST'])
def predict():
 # TODO: Implement prediction endpoint
 # Handle request, make prediction, return response
 pass

if __name__ == '__main__':
 app.run(debug=True, host='0.0.0.0', port=5000)

print('Local deployment server defined')

# %% [markdown]
# ## Testing Deployed Model
#
# Test the deployed model with various inputs.

# %%
import requests

def test_deployment(url, test_cases):
 
    """
 Test deployed model with various inputs
 """
 # TODO: Send test requests
 # Verify responses
 # Check error handling
 pass

print('Testing functions defined')
