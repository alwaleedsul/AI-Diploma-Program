# %% [markdown]
# # Exercise: Model Deployment with FastAPI
# ## AIAT 125 - Model Deployment
#
# ## Learning Objectives
# - Create REST API for ML model
# - Handle requests and responses
# - Implement error handling
# - Test API endpoints
#
# ## Real-World Context
# Deploy sentiment analysis API for customer feedback system.

# %% [markdown]
# ## 📥 Inputs & 📤 Outputs | المدخلات والمخرجات
#
# **Inputs:** What we use in this notebook
#
# - Libraries and concepts as introduced in this notebook; see prerequisites and code comments.
#
# **Outputs:** What you'll see when you run the cells
#
# - Printed results, figures, and summaries as shown when you run the cells.
#
# ---

# %%
# %pip install fastapi uvicorn pydantic scikit-learn -q
from fastapi import FastAPI
from pydantic import BaseModel
import pickle
print('✅ Setup complete!')

# %% [markdown]
# ## Task 1: API Structure (25 points)
#
# Create FastAPI app with endpoints.

# %%
# TODO: Create FastAPI app
app = FastAPI(title='Sentiment Analysis API')

class TextInput(BaseModel):
    text: str

# TODO: Add endpoints
@app.get('/')
def root():
    # YOUR CODE HERE
    pass

@app.post('/predict')
def predict(input: TextInput):
    # YOUR CODE HERE
    pass

# %% [markdown]
# ## Task 2: Model Loading (20 points)
#
# Load pre-trained model safely.

# %%
# TODO: Implement model loading
def load_model():
    # YOUR CODE HERE
    pass

# %% [markdown]
# ## Task 3: Error Handling (25 points)
#
# Add validation and error handling.

# %% [markdown]
# TODO: Add error handling
# from fastapi import HTTPException
#
# Add try-except blocks
# Validate input
# Return proper error messages

# %% [markdown]
# ## Task 4: Testing (30 points)
#
# Test API with sample requests.

# %% [markdown]
# TODO: Test API endpoints
# import requests
#
# Test health check
# Test prediction
# Test error cases

# %% [markdown]
# ## Submission
#
# **Total: 100 points**
#
# Real-world: Production ML APIs, microservices, customer service
