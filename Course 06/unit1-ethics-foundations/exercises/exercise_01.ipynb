# %% [markdown]
# # Unit 1: Foundations of AI Ethics

# %%
"""
Unit 1: Foundations of AI Ethics
Exercise 1: Ethical Framework Application
