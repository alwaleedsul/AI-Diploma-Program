# %% [markdown]
# # Applying Early Stopping and Regularization to Prevent Overfitting
#
# ## 📚 Learning Objectives
#
# By completing this notebook, you will:
# - Understand overfitting
# - Implement early stopping
# - Apply regularization techniques
# - Prevent overfitting
# - Improve generalization
#
# ## 🔗 Prerequisites
#
# - ✅ Understanding of training and validation
# - ✅ Understanding of overfitting
# - ✅ Keras knowledge
#
# ---
#
# ## Official Structure Reference
#
# This notebook covers practical activities from **Course 01, Unit 4**:
# - Applying early stopping and regularization to prevent overfitting
# - **Source:** `DETAILED_UNIT_DESCRIPTIONS.md` - Unit 4 Practical Content
#
# ---
#
# ## Introduction
#
# **Early stopping** and **regularization** prevent overfitting by stopping training when validation performance stops improving and penalizing complex models.

# %% [markdown]
# ## 📥 Inputs & 📤 Outputs | المدخلات والمخرجات
#
# **Inputs:** What we use in this notebook
#
# - Libraries and concepts as introduced in this notebook; see prerequisites and code comments.
#
# **Outputs:** What you'll see when you run the cells
#
# - Printed results, figures, and summaries as shown when you run the cells.
#
# ---

# %%
import numpy as np

print("✅ Libraries imported!")
print("\nEarly Stopping and Regularization")
print("=" * 60)

print("\nEarly Stopping:")
print("  - Monitor validation loss")
print("  - Stop when no improvement")
print("  - Prevents overfitting")
print("  - Saves best model")

print("\nRegularization:")
print("  - L1/L2 regularization")
print("  - Dropout")
print("  - Batch normalization")
print("  - Data augmentation")

print("\nBenefits:")
print("  - Better generalization")
print("  - Reduced overfitting")
print("  - Improved validation performance")

print("\n✅ Early stopping and regularization concepts understood!")
