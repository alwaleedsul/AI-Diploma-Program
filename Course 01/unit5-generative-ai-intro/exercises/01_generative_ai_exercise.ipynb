# %% [markdown]
# # Exercise: Generative AI Concepts
#
# ## 📝 Instructions
#
# Complete the following exercise to practice generative AI concepts.
#
# **Steps:**
# 1. Read each problem statement
# 2. Write your solution in the code cells
# 3. Run the code to test your solution
# 4. Check your output matches the expected results
#
# ---
#
# ## Problem Statement
#
# Apply your understanding of generative AI to solve real-world problems.

# %% [markdown]
# ## 📥 Inputs & 📤 Outputs | المدخلات والمخرجات
#
# **Inputs:** What we use in this notebook
#
# - Libraries and concepts as introduced in this notebook; see prerequisites and code comments.
#
# **Outputs:** What you'll see when you run the cells
#
# - Printed results, figures, and summaries as shown when you run the cells.
#
# ---

# %%
"""
Unit 5 - Exercise 1: Generative AI Concepts
الوحدة 5 - تمرين 1: مفاهيم الذكاء الاصطناعي التوليدي

Complete the following exercises.
"""

import numpy as np
import matplotlib.pyplot as plt

print("=" * 70)
print("Exercise 1: Generative AI Concepts")
print("=" * 70)

# Exercise 1: Identify Model Types
print("\nExercise 1: Identify Model Types")
print("-" * 70)

# TODO: Classify each model as Generative (G) or Discriminative (D)
models = {
    "Logistic Regression": None,  # TODO: Replace None with 'G' or 'D'
    "GAN (Generative Adversarial Network)": None,
    "Support Vector Machine": None,
    "VAE (Variational Autoencoder)": None,
    "Neural Network Classifier": None,
    "Naive Bayes": None
}

# TODO: Fill in your answers above, then uncomment below to check
# for model, answer in models.items():
#     print(f"{model}: {answer}")

# Exercise 2: Generate Synthetic Data
print("\nExercise 2: Generate Synthetic Data")
print("-" * 70)

# TODO: Write a function to generate synthetic data following a pattern
# Pattern: Generate points that form a square pattern
def generate_square_pattern(n_points=100):
    """
    Generate synthetic data points forming a square pattern.
    
    Args:
        n_points: Number of points to generate
    
    Returns:
        x, y: Arrays of x and y coordinates
    """
    # TODO: Implement this function
    # Hint: Generate points along the perimeter of a square
    x = np.array([])  # TODO: Replace with your implementation
    y = np.array([])  # TODO: Replace with your implementation
    return x, y

# TODO: Uncomment to test your function
# x_square, y_square = generate_square_pattern(200)
# plt.figure(figsize=(8, 8))
# plt.scatter(x_square, y_square, alpha=0.6)
# plt.title('Generated Square Pattern')
# plt.xlabel('X')
# plt.ylabel('Y')
# plt.grid(True, alpha=0.3)
# plt.axis('equal')
# plt.show()

# Exercise 3: Compare Approaches
print("\nExercise 3: Compare Generative vs Discriminative")
print("-" * 70)

# TODO: Complete the comparison table
comparison = {
    "What does it learn?": {
        "Generative": None,  # TODO: Fill in
        "Discriminative": None  # TODO: Fill in
    },
    "Can it generate new data?": {
        "Generative": None,  # TODO: Fill in (True/False)
        "Discriminative": None  # TODO: Fill in (True/False)
    },
    "Best use case": {
        "Generative": None,  # TODO: Fill in example
        "Discriminative": None  # TODO: Fill in example
    }
}

# TODO: Print your comparison
# for question, answers in comparison.items():
#     print(f"\n{question}")
#     for model_type, answer in answers.items():
#         print(f"  {model_type}: {answer}")

print("\n✅ Complete all TODOs above to finish the exercise!")
print("   Check solutions/01_generative_ai_solution.ipynb for answers.")
