# %% [markdown]
# # Exercise 01: Text Preprocessing\n
# ## AIAT 121 - Natural Language Processing\n
# \n
# ---\n
# \n
# ## Learning Objectives\n
# \n
# In this exercise, you will:\n
# - Apply text preprocessing techniques to real-world data\n
# - Clean and normalize text from social media posts\n
# - Compare different preprocessing strategies\n
# - Evaluate the impact of preprocessing on text analysis\n
# \n
# ---\n
# \n
# ## Real-World Context\n
# \n
# You are working for a social media analytics company that needs to analyze customer feedback from Twitter.\n
# \n
# Your task is to preprocess this data for sentiment analysis.

# %% [markdown]
# ## 📥 Inputs & 📤 Outputs | المدخلات والمخرجات
#
# **Inputs:** What we use in this notebook
#
# - Libraries and concepts as introduced in this notebook; see prerequisites and code comments.
#
# **Outputs:** What you'll see when you run the cells
#
# - Printed results, figures, and summaries as shown when you run the cells.
#
# ---

# %%
# Setup\n
# %pip install nltk pandas -q\n
\ni

# %% [markdown]
# ## Task 1: Clean Text (20 points)\n
# \n
# Write a function to clean text by removing URLs, mentions, hashtags, and special characters.

# %%
# TODO: Implement clean_text() function\
nd
ef clean_text(text):\n
