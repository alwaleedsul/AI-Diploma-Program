# %% [markdown]
# # Evaluating NLP Models Using Precision, Recall, F1-score
#
# ## 📚 Learning Objectives
#
# By completing this notebook, you will:
# - Compute precision for NLP models
# - Compute recall for NLP models
# - Compute F1-score
# - Analyze classification performance
# - Apply to text classification
#
# ## 🔗 Prerequisites
#
# - ✅ Understanding of classification metrics
# - ✅ Understanding of NLP models
# - ✅ Scikit-learn knowledge
#
# ---
#
# ## Official Structure Reference
#
# This notebook covers practical activities from **Course 07, Unit 3**:
# - Model evaluation metrics (Precision, Recall, F1-score)
# - **Source:** `DETAILED_UNIT_DESCRIPTIONS.md` - Unit 3 Practical Content
#
# ---
#
# ## Introduction
#
# **Evaluation metrics** for NLP models help assess performance, identify strengths and weaknesses, and compare different approaches.

# %% [markdown]
# ## 📥 Inputs & 📤 Outputs | المدخلات والمخرجات
#
# **Inputs:** What we use in this notebook
#
# - Libraries and concepts as introduced in this notebook; see prerequisites and code comments.
#
# **Outputs:** What you'll see when you run the cells
#
# - Printed results, figures, and summaries as shown when you run the cells.
#
# ---

# %%
import numpy as np
from sklearn.metrics import precision_score, recall_score, f1_score, accuracy_score
from sklearn.metrics import classification_report, confusion_matrix
